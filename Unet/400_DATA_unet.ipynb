# %% [markdown]
# # UNET WEBPAGE SEGMENTATION

# %%
# %pip install tensorflow==1.15.0
# Out:
# Requirement already satisfied: tensorflow==1.15.0 in /usr/local/lib/python3.6/dist-packages (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (3.2.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.15.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.30.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.18.5)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.12.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (3.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.1.2)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (47.3.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.0) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (1.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.1.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
from PIL import Image

# from tensorflow import keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *


#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K


from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
from tensorflow.compat.v1.layers import conv2d_transpose
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
os.environ['DISABLE_COLAB_TF_IMPORT_HOOK'] = '1'
tf.enable_eager_execution()

# %% [markdown]
# # Environment checks

# %%
print(tf.__version__)

x = tf.random.uniform([3, 3])

print("Is there a GPU available: "),
print(tf.test.is_gpu_available())

print("Is the Tensor on GPU #0:  "),
print(x.device.endswith('GPU:0'))

print("Device name: {}".format((x.device)))

print(tf.executing_eagerly())
# Out:
# 1.15.0
# Is there a GPU available:
# False
# Is the Tensor on GPU #0:
# False
# Device name: /job:localhost/replica:0/task:0/device:CPU:0
# True

# %% [markdown]
# ## Data preparation - Importing, Cleaning and Creating structured directory

# %% [markdown]
# ### Function to import and process frames and masks as tensors

# %%
def _read_to_tensor(fname, output_height=256, output_width=256, normalize_data=False):
    '''Function to read images from given image file path, and provide resized images as tensors
        Inputs: 
            fname - image file path
            output_height - required output image height
            output_width - required output image width
            normalize_data - if True, normalize data to be centered around 0 (mean 0, range 0 to 1)
        Output: Processed image tensors
    '''
    
    # Read the image as a tensor
    img_strings = tf.io.read_file(fname)
    imgs_decoded = tf.image.decode_jpeg(img_strings)
    
    # Resize the image
    output = tf.image.resize(imgs_decoded, [output_height, output_width])
    
    # Normalize if required
    if normalize_data:
        output = (output - 128) / 128
    return output

# %% [markdown]
# ### Image directory and size parameters

# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img_dir = '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/'

# Required image dimensions
output_height = 256
output_width = 256

# %% [markdown]
# ### Reading frames and masks
# - Mask file names end in "\_L.png"

# %%
def read_images(img_dir):
    '''Function to get all image directories, read images and masks in separate tensors
        Inputs: 
            img_dir - file directory
        Outputs 
            frame_tensors, masks_tensors, frame files list, mask files list
    '''
    
    # Get the file names list from provided directory
    file_list = [f for f in os.listdir(img_dir) if os.path.isfile(os.path.join(img_dir, f))]
    
    # Separate frame and mask files lists, exclude unnecessary files
    frames_list = [file for file in file_list if ('_L' not in file) and ('txt' not in file)]
    masks_list = [file for file in file_list if ('_L' in file) and ('txt' not in file)]
    frames_list.sort()
    masks_list.sort()
    print('{} frame files found in the provided directory.'.format(len(frames_list)))
    print('{} mask files found in the provided directory.'.format(len(masks_list)))
    
    # Create file paths from file names
    frames_paths = [os.path.join(img_dir, fname) for fname in frames_list]
    masks_paths = [os.path.join(img_dir, fname) for fname in masks_list]
    
    # Create dataset of tensors
    frame_data = tf.data.Dataset.from_tensor_slices(frames_paths)
    masks_data = tf.data.Dataset.from_tensor_slices(masks_paths)
    
    # Read images into the tensor dataset
    frame_tensors = frame_data.map(_read_to_tensor)
    masks_tensors = masks_data.map(_read_to_tensor)
    
    print('Completed importing {} frame images from the provided directory.'.format(len(frames_list)))
    print('Completed importing {} mask images from the provided directory.'.format(len(masks_list)))
    
    return frame_tensors, masks_tensors, frames_list, masks_list

frame_tensors, masks_tensors, frames_list, masks_list = read_images(img_dir)
# Out:
# 400 frame files found in the provided directory.
# 400 mask files found in the provided directory.
# Completed importing 400 frame images from the provided directory.
# Completed importing 400 mask images from the provided directory.

# %%
# Make an iterator to extract images from the tensor dataset
frame_batches = tf.compat.v1.data.make_one_shot_iterator(frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks_tensors)


n_images_to_show = 5

for i in range(n_images_to_show):
    
    # Get the next image from iterator
    frame = frame_batches.next().numpy().astype(np.uint8)
    mask = mask_batches.next().numpy().astype(np.uint8)
    
    #Plot the corresponding frames and masks
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.imshow(frame)
    fig.add_subplot(1,2,2)
    plt.imshow(mask)
    plt.show()

# %% [markdown]
# ### Creating folder structure common for Computer Vision problems

# %%
DATA_PATH = '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/'

# Create folders to hold images and masks

folders = ['train_frames/train', 'train_masks/train', 'val_frames/val', 'val_masks/val']


for folder in folders:
    try:
        os.makedirs(DATA_PATH + folder)
    except Exception as e: print(e)
# Out:
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/train_frames/train'
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/train_masks/train'
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/val_frames/val'
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/val_masks/val'

# %% [markdown]
# ### Saving frames and masks to correct directories

# %%
def generate_image_folder_structure(frames, masks, frames_list, masks_list):
    '''Function to save images in the appropriate folder directories 
        Inputs: 
            frames - frame tensor dataset
            masks - mask tensor dataset
            frames_list - frame file paths
            masks_list - mask file paths
    '''
    #Create iterators for frames and masks
    frame_batches = tf.compat.v1.data.make_one_shot_iterator(frames)  # outside of TF Eager, we would use make_one_shot_iterator
    mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks)
    
    #Iterate over the train images while saving the frames and masks in appropriate folders
    dir_name='train'
    for file in zip(frames_list[:-round(0.2*len(frames_list))],masks_list[:-round(0.2*len(masks_list))]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    #Iterate over the val images while saving the frames and masks in appropriate folders
    dir_name='val'
    for file in zip(frames_list[-round(0.2*len(frames_list)):],masks_list[-round(0.2*len(masks_list)):]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    print("Saved {} frames to directory {}".format(len(frames_list),DATA_PATH))
    print("Saved {} masks to directory {}".format(len(masks_list),DATA_PATH))
    
generate_image_folder_structure(frame_tensors, masks_tensors, frames_list, masks_list)

#generate_image_folder_structure(train_frames, train_masks, val_files, 'val')
# Out:
# Saved 400 frames to directory /content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_3_MERGED/
# Saved 400 masks to directory /content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_3_MERGED/

# %% [markdown]
# ## Extract Target Class definitions

# %% [markdown]
# ### Function to parse the file "label_colors.txt" which contains the class definitions

# %%
def parse_code(l):
    '''Function to parse lines in a text file, returns separated elements (label codes and names in this case)
    '''
    if len(l.strip().split("\t")) == 2:
        a, b = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), b
    else:
        a, b, c = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), c

# %% [markdown]
# ### Parse and extract label names and codes

# %%
label_codes, label_names = zip(*[parse_code(l) for l in open("label_colors.txt")])
label_codes, label_names = list(label_codes), list(label_names)
label_codes[:5], label_names[:5]
# Out:
# ([(255, 255, 255), (255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 0, 255)],
#  ['Background', 'Image', 'Text', 'FormElement', 'Container'])

# %%
label_codes, label_names
# Out:
# ([(255, 255, 255), (255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 0, 255)],
#  ['Background', 'Image', 'Text', 'FormElement', 'Container'])

# %% [markdown]
# ### Create useful label and code conversion dictionaries
# _These will be used for:_
# - One hot encoding the mask labels for model training
# - Decoding the predicted labels for interpretation and visualization

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}

# %%
name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
id2code
# Out:
# {0: (255, 255, 255),
#  1: (255, 0, 0),
#  2: (0, 255, 0),
#  3: (0, 0, 255),
#  4: (255, 0, 255)}

# %%
id2name
# Out:
# {0: 'Background', 1: 'Image', 2: 'Text', 3: 'FormElement', 4: 'Container'}

# %% [markdown]
# ### Define functions for one hot encoding rgb labels, and decoding encoded predictions

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: 
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    num_classes = len(colormap)
    shape = rgb_image.shape[:2]+(num_classes,)
    encoded_image = np.zeros( shape, dtype=np.int8 )
    for i, cls in enumerate(colormap):
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %% [markdown]
# # Creating custom Image data generators

# %% [markdown]
# ### Defining data generators

# %%
# Normalizing only frame images, since masks contain label info
data_gen_args = dict(rescale=1./255)
mask_gen_args = dict()

train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)

# Seed defined for aligning images and their masks
seed = 1

# %% [markdown]
# ### Custom image data generators for creating batches of frames and masks

# %%
def TrainAugmentGenerator(seed = 1, batch_size = 16):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    train_image_generator = train_frames_datagen.flow_from_directory(
    DATA_PATH + 'train_frames/',
    batch_size = batch_size, seed = seed)

    train_mask_generator = train_masks_datagen.flow_from_directory(
    DATA_PATH + 'train_masks/',
    batch_size = batch_size, seed = seed)

    while True:
        X1i = train_image_generator.next()
        X2i = train_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

def ValAugmentGenerator(seed = 1, batch_size = 16):
    '''Validation Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    val_image_generator = val_frames_datagen.flow_from_directory(
    DATA_PATH + 'val_frames/',
    batch_size = batch_size, seed = seed)


    val_mask_generator = val_masks_datagen.flow_from_directory(
    DATA_PATH + 'val_masks/',
    batch_size = batch_size, seed = seed)


    while True:
        X1i = val_image_generator.next()
        X2i = val_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

# %%
def get_small_unet(n_filters = 16, bn = True, dilation_rate = 1):
    '''Validation Image data generator
        Inputs: 
            n_filters - base convolution filters
            bn - flag to set batch normalization
            dilation_rate - convolution dilation rate
        Output: Unet keras Model
    '''
    #Define input batch shape
    batch_shape=(256,256,3)
    inputs = Input(batch_shape=(16, 256, 256, 3))
    print(inputs)
    
    conv1 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(inputs)
    if bn:
        conv1 = BatchNormalization()(conv1)
        
    conv1 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv1)
    if bn:
        conv1 = BatchNormalization()(conv1)
    
    pool1 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv1)

    conv2 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool1)
    if bn:
        conv2 = BatchNormalization()(conv2)
        
    conv2 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv2)
    if bn:
        conv2 = BatchNormalization()(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv2)

    conv3 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool2)
    if bn:
        conv3 = BatchNormalization()(conv3)
        
    conv3 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv3)
    if bn:
        conv3 = BatchNormalization()(conv3)
        
    pool3 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv3)

    conv4 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool3)
    if bn:
        conv4 = BatchNormalization()(conv4)
        
    conv4 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv4)
    if bn:
        conv4 = BatchNormalization()(conv4)
        
    pool4 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv4)

    conv5 = Conv2D(n_filters * 16, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool4)
    if bn:
        conv5 = BatchNormalization()(conv5)
        
    conv5 = Conv2D(n_filters * 16, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv5)
    if bn:
        conv5 = BatchNormalization()(conv5)
        
    up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv4], axis=3)
    
    conv6 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up6)
    if bn:
        conv6 = BatchNormalization()(conv6)
        
    conv6 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv6)
    if bn:
        conv6 = BatchNormalization()(conv6)
        
    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv3], axis=3)
    
    conv7 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up7)
    if bn:
        conv7 = BatchNormalization()(conv7)
        
    conv7 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv7)
    if bn:
        conv7 = BatchNormalization()(conv7)
        
    up8 = concatenate([UpSampling2D(size=(2, 2))(conv7), conv2], axis=3)
    
    conv8 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up8)
    if bn:
        conv8 = BatchNormalization()(conv8)
        
    conv8 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv8)
    if bn:
        conv8 = BatchNormalization()(conv8)
        
    up9 = concatenate([UpSampling2D(size=(2, 2))(conv8), conv1], axis=3)
    
    conv9 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up9)
    if bn:
        conv9 = BatchNormalization()(conv9)
        
    conv9 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv9)
    if bn:
        conv9 = BatchNormalization()(conv9)
        
    conv10 = Conv2D(5, (1, 1), activation='softmax', padding = 'same', dilation_rate = dilation_rate)(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    
    return model

# %% [markdown]
# ## Generating U-Net model

# %%
model = get_small_unet(n_filters = 32)
# Out:
# Tensor("input_1:0", shape=(16, 256, 256, 3), dtype=float32)

# %% [markdown]
# ## Defining dice co-efficients for model performance

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

  

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %% [markdown]
# ## Compiling model
# - Using categorical crossentropy loss since labels have been one hot encoded

# %%
  smooth = 1.

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=[tversky_loss,dice_coef,'accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(16, 256, 256, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (16, 256, 256, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (16, 256, 256, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (16, 256, 256, 32)   9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (16, 256, 256, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (16, 128, 128, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (16, 128, 128, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (16, 128, 128, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (16, 128, 128, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (16, 128, 128, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (16, 64, 64, 64)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (16, 64, 64, 128)    73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (16, 64, 64, 128)    512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (16, 64, 64, 128)    147584      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (16, 64, 64, 128)    512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (16, 32, 32, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (16, 32, 32, 256)    295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (16, 32, 32, 256)    1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (16, 32, 32, 256)    590080      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (16, 32, 32, 256)    1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (16, 16, 16, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (16, 16, 16, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (16, 16, 16, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (16, 16, 16, 512)    2359808     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (16, 16, 16, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (16, 32, 32, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (16, 32, 32, 768)    0           up_sampling2d[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (16, 32, 32, 256)    1769728     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (16, 32, 32, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (16, 32, 32, 256)    590080      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (16, 32, 32, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (16, 64, 64, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (16, 64, 64, 384)    0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (16, 64, 64, 128)    442496      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (16, 64, 64, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (16, 64, 64, 128)    147584      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (16, 64, 64, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (16, 128, 128, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (16, 128, 128, 192)  0           up_sampling2d_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (16, 128, 128, 64)   110656      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (16, 128, 128, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (16, 128, 128, 64)   36928       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (16, 128, 128, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (16, 256, 256, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (16, 256, 256, 96)   0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (16, 256, 256, 32)   27680       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (16, 256, 256, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (16, 256, 256, 32)   9248        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (16, 256, 256, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (16, 256, 256, 5)    165         batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 7,858,565
# Trainable params: 7,852,677
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# ## Define model callback settings

# %%
tb = TensorBoard(log_dir='logs', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='Unet_guided1_100_epochs_checkpoint.h5', monitor='val_acc', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='max', monitor='val_acc', patience=10, verbose=1)
callbacks = [tb, mc]

# %% [markdown]
# ## Train and save the U-Net model

# %%
batch_size = 16
steps_per_epoch = np.ceil(float(len(frames_list) - round(0.1*len(frames_list))) / float(batch_size))
steps_per_epoch
# Out:
# 23.0

# %%
validation_steps = (float((round(0.1*len(frames_list)))) / float(batch_size))
validation_steps
# Out:
# 2.5

# %%
num_epochs = 100

# %%
# Train model


result = model.fit_generator(TrainAugmentGenerator(), steps_per_epoch=18 ,
                validation_data = ValAugmentGenerator(), 
                validation_steps = validation_steps, epochs=num_epochs, callbacks=callbacks)
model.save_weights("Unet_guided1_100_epochs.h5", overwrite=True)
# Out:
# Found 320 images belonging to 1 classes.
# Epoch 1/100
# Found 320 images belonging to 1 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1394: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 17/18 [===========================>..] - ETA: 1s - loss: 1.1645 - tversky_loss: 4.5276 - dice_coef: 0.6252 - acc: 0.5936Epoch 1/100
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
#  3/18 [====>.........................] - ETA: 8s - loss: 7.4834 - tversky_loss: 4.8075 - dice_coef: 0.2181 - acc: 0.1964
# Epoch 00001: val_acc improved from -inf to 0.19635, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 28s 2s/step - loss: 1.1460 - tversky_loss: 4.5215 - dice_coef: 0.6321 - acc: 0.6009 - val_loss: 8.9800 - val_tversky_loss: 4.8075 - val_dice_coef: 0.2181 - val_acc: 0.1964
# Epoch 2/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.8064 - tversky_loss: 4.4076 - dice_coef: 0.7471 - acc: 0.7141Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 2.4548 - tversky_loss: 4.5702 - dice_coef: 0.5270 - acc: 0.4941
# Epoch 00002: val_acc improved from 0.19635 to 0.49408, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.8151 - tversky_loss: 4.4097 - dice_coef: 0.7444 - acc: 0.7103 - val_loss: 2.9458 - val_tversky_loss: 4.5702 - val_dice_coef: 0.5270 - val_acc: 0.4941
# Epoch 3/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.7637 - tversky_loss: 4.3972 - dice_coef: 0.7577 - acc: 0.7229Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 8.3937 - tversky_loss: 4.6466 - dice_coef: 0.3582 - acc: 0.3514
# Epoch 00003: val_acc did not improve from 0.49408
# 18/18 [==============================] - 20s 1s/step - loss: 0.7680 - tversky_loss: 4.3981 - dice_coef: 0.7558 - acc: 0.7194 - val_loss: 10.0724 - val_tversky_loss: 4.6466 - val_dice_coef: 0.3582 - val_acc: 0.3514
# Epoch 4/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.7083 - tversky_loss: 4.3681 - dice_coef: 0.7800 - acc: 0.7459Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 2.3349 - tversky_loss: 4.6170 - dice_coef: 0.4360 - acc: 0.3548
# Epoch 00004: val_acc did not improve from 0.49408
# 18/18 [==============================] - 19s 1s/step - loss: 0.7025 - tversky_loss: 4.3667 - dice_coef: 0.7817 - acc: 0.7485 - val_loss: 2.8019 - val_tversky_loss: 4.6170 - val_dice_coef: 0.4360 - val_acc: 0.3548
# Epoch 5/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.6966 - tversky_loss: 4.3547 - dice_coef: 0.7864 - acc: 0.7461Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.5245 - tversky_loss: 4.6085 - dice_coef: 0.5172 - acc: 0.4986
# Epoch 00005: val_acc improved from 0.49408 to 0.49859, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.6913 - tversky_loss: 4.3531 - dice_coef: 0.7874 - acc: 0.7477 - val_loss: 1.8294 - val_tversky_loss: 4.6085 - val_dice_coef: 0.5172 - val_acc: 0.4986
# Epoch 6/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.6420 - tversky_loss: 4.3339 - dice_coef: 0.8022 - acc: 0.7687Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 5.0871 - tversky_loss: 4.7221 - dice_coef: 0.3563 - acc: 0.3408
# Epoch 00006: val_acc did not improve from 0.49859
# 18/18 [==============================] - 20s 1s/step - loss: 0.6360 - tversky_loss: 4.3320 - dice_coef: 0.8042 - acc: 0.7718 - val_loss: 6.1045 - val_tversky_loss: 4.7221 - val_dice_coef: 0.3563 - val_acc: 0.3408
# Epoch 7/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.6647 - tversky_loss: 4.3428 - dice_coef: 0.7925 - acc: 0.7535Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 5.3964 - tversky_loss: 4.6542 - dice_coef: 0.3538 - acc: 0.3409
# Epoch 00007: val_acc did not improve from 0.49859
# 18/18 [==============================] - 20s 1s/step - loss: 0.6638 - tversky_loss: 4.3426 - dice_coef: 0.7931 - acc: 0.7538 - val_loss: 6.4757 - val_tversky_loss: 4.6542 - val_dice_coef: 0.3538 - val_acc: 0.3409
# Epoch 8/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.6196 - tversky_loss: 4.3241 - dice_coef: 0.8090 - acc: 0.7702Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 2.3010 - tversky_loss: 4.6258 - dice_coef: 0.4222 - acc: 0.3709
# Epoch 00008: val_acc did not improve from 0.49859
# 18/18 [==============================] - 20s 1s/step - loss: 0.6245 - tversky_loss: 4.3248 - dice_coef: 0.8079 - acc: 0.7690 - val_loss: 2.7612 - val_tversky_loss: 4.6258 - val_dice_coef: 0.4222 - val_acc: 0.3709
# Epoch 9/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.6226 - tversky_loss: 4.3263 - dice_coef: 0.8063 - acc: 0.7694Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 2.4028 - tversky_loss: 4.6371 - dice_coef: 0.4155 - acc: 0.3450
# Epoch 00009: val_acc did not improve from 0.49859
# 18/18 [==============================] - 20s 1s/step - loss: 0.6184 - tversky_loss: 4.3250 - dice_coef: 0.8079 - acc: 0.7717 - val_loss: 2.8833 - val_tversky_loss: 4.6371 - val_dice_coef: 0.4155 - val_acc: 0.3450
# Epoch 10/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5936 - tversky_loss: 4.3080 - dice_coef: 0.8172 - acc: 0.7792Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 5.0686 - tversky_loss: 4.6454 - dice_coef: 0.3665 - acc: 0.3480
# Epoch 00010: val_acc did not improve from 0.49859
# 18/18 [==============================] - 20s 1s/step - loss: 0.6004 - tversky_loss: 4.3101 - dice_coef: 0.8151 - acc: 0.7755 - val_loss: 6.0824 - val_tversky_loss: 4.6454 - val_dice_coef: 0.3665 - val_acc: 0.3480
# Epoch 11/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.6001 - tversky_loss: 4.3165 - dice_coef: 0.8145 - acc: 0.7784Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 4.5658 - tversky_loss: 4.6427 - dice_coef: 0.3836 - acc: 0.3745
# Epoch 00011: val_acc did not improve from 0.49859
# 18/18 [==============================] - 20s 1s/step - loss: 0.5923 - tversky_loss: 4.3138 - dice_coef: 0.8170 - acc: 0.7810 - val_loss: 5.4790 - val_tversky_loss: 4.6427 - val_dice_coef: 0.3836 - val_acc: 0.3745
# Epoch 12/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5544 - tversky_loss: 4.2919 - dice_coef: 0.8321 - acc: 0.8009Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 4.6482 - tversky_loss: 4.6540 - dice_coef: 0.3646 - acc: 0.3582
# Epoch 00012: val_acc did not improve from 0.49859
# 18/18 [==============================] - 20s 1s/step - loss: 0.5576 - tversky_loss: 4.2913 - dice_coef: 0.8317 - acc: 0.8003 - val_loss: 5.5778 - val_tversky_loss: 4.6540 - val_dice_coef: 0.3646 - val_acc: 0.3582
# Epoch 13/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5653 - tversky_loss: 4.2975 - dice_coef: 0.8260 - acc: 0.7870Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 2.2335 - tversky_loss: 4.5711 - dice_coef: 0.5176 - acc: 0.5058
# Epoch 00013: val_acc improved from 0.49859 to 0.50581, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5623 - tversky_loss: 4.2964 - dice_coef: 0.8270 - acc: 0.7888 - val_loss: 2.6802 - val_tversky_loss: 4.5711 - val_dice_coef: 0.5176 - val_acc: 0.5058
# Epoch 14/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5461 - tversky_loss: 4.2884 - dice_coef: 0.8344 - acc: 0.8034Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 3.0159 - tversky_loss: 4.5755 - dice_coef: 0.4710 - acc: 0.4346
# Epoch 00014: val_acc did not improve from 0.50581
# 18/18 [==============================] - 20s 1s/step - loss: 0.5436 - tversky_loss: 4.2872 - dice_coef: 0.8351 - acc: 0.8042 - val_loss: 3.6191 - val_tversky_loss: 4.5755 - val_dice_coef: 0.4710 - val_acc: 0.4346
# Epoch 15/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5516 - tversky_loss: 4.2865 - dice_coef: 0.8312 - acc: 0.7927Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 2.4401 - tversky_loss: 4.5683 - dice_coef: 0.4941 - acc: 0.4675
# Epoch 00015: val_acc did not improve from 0.50581
# 18/18 [==============================] - 20s 1s/step - loss: 0.5488 - tversky_loss: 4.2861 - dice_coef: 0.8320 - acc: 0.7940 - val_loss: 2.9282 - val_tversky_loss: 4.5683 - val_dice_coef: 0.4941 - val_acc: 0.4675
# Epoch 16/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5314 - tversky_loss: 4.2804 - dice_coef: 0.8376 - acc: 0.8014Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.8691 - tversky_loss: 4.5738 - dice_coef: 0.4969 - acc: 0.4285
# Epoch 00016: val_acc did not improve from 0.50581
# 18/18 [==============================] - 20s 1s/step - loss: 0.5293 - tversky_loss: 4.2796 - dice_coef: 0.8382 - acc: 0.8020 - val_loss: 2.2430 - val_tversky_loss: 4.5738 - val_dice_coef: 0.4969 - val_acc: 0.4285
# Epoch 17/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5496 - tversky_loss: 4.2885 - dice_coef: 0.8315 - acc: 0.7935Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.3880 - tversky_loss: 4.5008 - dice_coef: 0.6098 - acc: 0.5922
# Epoch 00017: val_acc improved from 0.50581 to 0.59218, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5452 - tversky_loss: 4.2875 - dice_coef: 0.8328 - acc: 0.7958 - val_loss: 1.6655 - val_tversky_loss: 4.5008 - val_dice_coef: 0.6098 - val_acc: 0.5922
# Epoch 18/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5578 - tversky_loss: 4.2893 - dice_coef: 0.8286 - acc: 0.7894Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.6369 - tversky_loss: 4.5653 - dice_coef: 0.5184 - acc: 0.3926
# Epoch 00018: val_acc did not improve from 0.59218
# 18/18 [==============================] - 20s 1s/step - loss: 0.5608 - tversky_loss: 4.2906 - dice_coef: 0.8276 - acc: 0.7877 - val_loss: 1.9643 - val_tversky_loss: 4.5653 - val_dice_coef: 0.5184 - val_acc: 0.3926
# Epoch 19/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5313 - tversky_loss: 4.2836 - dice_coef: 0.8354 - acc: 0.7940Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.2086 - tversky_loss: 4.4990 - dice_coef: 0.6168 - acc: 0.5097
# Epoch 00019: val_acc did not improve from 0.59218
# 18/18 [==============================] - 20s 1s/step - loss: 0.5273 - tversky_loss: 4.2821 - dice_coef: 0.8368 - acc: 0.7965 - val_loss: 1.4503 - val_tversky_loss: 4.4990 - val_dice_coef: 0.6168 - val_acc: 0.5097
# Epoch 20/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5254 - tversky_loss: 4.2769 - dice_coef: 0.8404 - acc: 0.8053Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.3499 - tversky_loss: 4.4694 - dice_coef: 0.6323 - acc: 0.6108
# Epoch 00020: val_acc improved from 0.59218 to 0.61075, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5260 - tversky_loss: 4.2769 - dice_coef: 0.8400 - acc: 0.8038 - val_loss: 1.6199 - val_tversky_loss: 4.4694 - val_dice_coef: 0.6323 - val_acc: 0.6108
# Epoch 21/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5057 - tversky_loss: 4.2672 - dice_coef: 0.8449 - acc: 0.8068Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.1957 - tversky_loss: 4.4682 - dice_coef: 0.6524 - acc: 0.6353
# Epoch 00021: val_acc improved from 0.61075 to 0.63525, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5011 - tversky_loss: 4.2660 - dice_coef: 0.8465 - acc: 0.8095 - val_loss: 1.4348 - val_tversky_loss: 4.4682 - val_dice_coef: 0.6524 - val_acc: 0.6353
# Epoch 22/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4815 - tversky_loss: 4.2565 - dice_coef: 0.8548 - acc: 0.8244Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.1262 - tversky_loss: 4.4037 - dice_coef: 0.6984 - acc: 0.6588
# Epoch 00022: val_acc improved from 0.63525 to 0.65882, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.4837 - tversky_loss: 4.2571 - dice_coef: 0.8540 - acc: 0.8228 - val_loss: 1.3514 - val_tversky_loss: 4.4037 - val_dice_coef: 0.6984 - val_acc: 0.6588
# Epoch 23/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.5059 - tversky_loss: 4.2722 - dice_coef: 0.8436 - acc: 0.8090Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.1191 - tversky_loss: 4.4454 - dice_coef: 0.6638 - acc: 0.6068
# Epoch 00023: val_acc did not improve from 0.65882
# 18/18 [==============================] - 20s 1s/step - loss: 0.5055 - tversky_loss: 4.2723 - dice_coef: 0.8438 - acc: 0.8094 - val_loss: 1.3429 - val_tversky_loss: 4.4454 - val_dice_coef: 0.6638 - val_acc: 0.6068
# Epoch 24/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4902 - tversky_loss: 4.2608 - dice_coef: 0.8500 - acc: 0.8148Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.9838 - tversky_loss: 4.4114 - dice_coef: 0.7024 - acc: 0.6475
# Epoch 00024: val_acc did not improve from 0.65882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4889 - tversky_loss: 4.2609 - dice_coef: 0.8503 - acc: 0.8153 - val_loss: 1.1806 - val_tversky_loss: 4.4114 - val_dice_coef: 0.7024 - val_acc: 0.6475
# Epoch 25/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4791 - tversky_loss: 4.2561 - dice_coef: 0.8535 - acc: 0.8161Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.9618 - tversky_loss: 4.4561 - dice_coef: 0.6762 - acc: 0.5972
# Epoch 00025: val_acc did not improve from 0.65882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4801 - tversky_loss: 4.2568 - dice_coef: 0.8533 - acc: 0.8160 - val_loss: 1.1542 - val_tversky_loss: 4.4561 - val_dice_coef: 0.6762 - val_acc: 0.5972
# Epoch 26/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4811 - tversky_loss: 4.2560 - dice_coef: 0.8534 - acc: 0.8181Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.0152 - tversky_loss: 4.4506 - dice_coef: 0.6698 - acc: 0.5759
# Epoch 00026: val_acc did not improve from 0.65882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4795 - tversky_loss: 4.2558 - dice_coef: 0.8536 - acc: 0.8178 - val_loss: 1.2183 - val_tversky_loss: 4.4506 - val_dice_coef: 0.6698 - val_acc: 0.5759
# Epoch 27/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4807 - tversky_loss: 4.2505 - dice_coef: 0.8548 - acc: 0.8200Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.8767 - tversky_loss: 4.3804 - dice_coef: 0.7389 - acc: 0.7093
# Epoch 00027: val_acc improved from 0.65882 to 0.70925, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.4798 - tversky_loss: 4.2511 - dice_coef: 0.8549 - acc: 0.8199 - val_loss: 1.0520 - val_tversky_loss: 4.3804 - val_dice_coef: 0.7389 - val_acc: 0.7093
# Epoch 28/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4514 - tversky_loss: 4.2449 - dice_coef: 0.8640 - acc: 0.8325Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6765 - tversky_loss: 4.2799 - dice_coef: 0.8112 - acc: 0.7688
# Epoch 00028: val_acc improved from 0.70925 to 0.76882, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.4531 - tversky_loss: 4.2450 - dice_coef: 0.8634 - acc: 0.8316 - val_loss: 0.8118 - val_tversky_loss: 4.2799 - val_dice_coef: 0.8112 - val_acc: 0.7688
# Epoch 29/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4479 - tversky_loss: 4.2371 - dice_coef: 0.8663 - acc: 0.8367Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7278 - tversky_loss: 4.2872 - dice_coef: 0.8040 - acc: 0.7668
# Epoch 00029: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4486 - tversky_loss: 4.2366 - dice_coef: 0.8661 - acc: 0.8364 - val_loss: 0.8734 - val_tversky_loss: 4.2872 - val_dice_coef: 0.8040 - val_acc: 0.7668
# Epoch 30/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4347 - tversky_loss: 4.2304 - dice_coef: 0.8696 - acc: 0.8389Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7709 - tversky_loss: 4.2914 - dice_coef: 0.7922 - acc: 0.7449
# Epoch 00030: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4357 - tversky_loss: 4.2309 - dice_coef: 0.8692 - acc: 0.8378 - val_loss: 0.9250 - val_tversky_loss: 4.2914 - val_dice_coef: 0.7922 - val_acc: 0.7449
# Epoch 31/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4096 - tversky_loss: 4.2186 - dice_coef: 0.8790 - acc: 0.8500Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.0318 - tversky_loss: 4.4327 - dice_coef: 0.6747 - acc: 0.5839
# Epoch 00031: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4146 - tversky_loss: 4.2200 - dice_coef: 0.8776 - acc: 0.8486 - val_loss: 1.2381 - val_tversky_loss: 4.4327 - val_dice_coef: 0.6747 - val_acc: 0.5839
# Epoch 32/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4248 - tversky_loss: 4.2256 - dice_coef: 0.8734 - acc: 0.8436Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7910 - tversky_loss: 4.3731 - dice_coef: 0.7475 - acc: 0.6896
# Epoch 00032: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4216 - tversky_loss: 4.2251 - dice_coef: 0.8741 - acc: 0.8441 - val_loss: 0.9491 - val_tversky_loss: 4.3731 - val_dice_coef: 0.7475 - val_acc: 0.6896
# Epoch 33/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4249 - tversky_loss: 4.2270 - dice_coef: 0.8732 - acc: 0.8434Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7226 - tversky_loss: 4.2789 - dice_coef: 0.8071 - acc: 0.7653
# Epoch 00033: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4185 - tversky_loss: 4.2245 - dice_coef: 0.8754 - acc: 0.8463 - val_loss: 0.8672 - val_tversky_loss: 4.2789 - val_dice_coef: 0.8071 - val_acc: 0.7653
# Epoch 34/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4257 - tversky_loss: 4.2201 - dice_coef: 0.8748 - acc: 0.8454Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7728 - tversky_loss: 4.3632 - dice_coef: 0.7555 - acc: 0.6993
# Epoch 00034: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4234 - tversky_loss: 4.2193 - dice_coef: 0.8756 - acc: 0.8468 - val_loss: 0.9274 - val_tversky_loss: 4.3632 - val_dice_coef: 0.7555 - val_acc: 0.6993
# Epoch 35/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4172 - tversky_loss: 4.2246 - dice_coef: 0.8746 - acc: 0.8437Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7213 - tversky_loss: 4.3274 - dice_coef: 0.7835 - acc: 0.7351
# Epoch 00035: val_acc did not improve from 0.76882
# 18/18 [==============================] - 19s 1s/step - loss: 0.4118 - tversky_loss: 4.2228 - dice_coef: 0.8763 - acc: 0.8459 - val_loss: 0.8656 - val_tversky_loss: 4.3274 - val_dice_coef: 0.7835 - val_acc: 0.7351
# Epoch 36/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3916 - tversky_loss: 4.2086 - dice_coef: 0.8842 - acc: 0.8564Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7543 - tversky_loss: 4.3621 - dice_coef: 0.7546 - acc: 0.6947
# Epoch 00036: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.3907 - tversky_loss: 4.2084 - dice_coef: 0.8846 - acc: 0.8571 - val_loss: 0.9051 - val_tversky_loss: 4.3621 - val_dice_coef: 0.7546 - val_acc: 0.6947
# Epoch 37/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3882 - tversky_loss: 4.2061 - dice_coef: 0.8870 - acc: 0.8620Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6313 - tversky_loss: 4.2880 - dice_coef: 0.8118 - acc: 0.7664
# Epoch 00037: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.3839 - tversky_loss: 4.2047 - dice_coef: 0.8882 - acc: 0.8634 - val_loss: 0.7576 - val_tversky_loss: 4.2880 - val_dice_coef: 0.8118 - val_acc: 0.7664
# Epoch 38/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3977 - tversky_loss: 4.2060 - dice_coef: 0.8833 - acc: 0.8544Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.8522 - tversky_loss: 4.3967 - dice_coef: 0.7249 - acc: 0.6664
# Epoch 00038: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.3938 - tversky_loss: 4.2051 - dice_coef: 0.8844 - acc: 0.8556 - val_loss: 1.0227 - val_tversky_loss: 4.3967 - val_dice_coef: 0.7249 - val_acc: 0.6664
# Epoch 39/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.4143 - tversky_loss: 4.2206 - dice_coef: 0.8773 - acc: 0.8503Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.6236 - tversky_loss: 4.4423 - dice_coef: 0.6138 - acc: 0.5752
# Epoch 00039: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.4087 - tversky_loss: 4.2185 - dice_coef: 0.8789 - acc: 0.8521 - val_loss: 1.9483 - val_tversky_loss: 4.4423 - val_dice_coef: 0.6138 - val_acc: 0.5752
# Epoch 40/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3561 - tversky_loss: 4.1910 - dice_coef: 0.8962 - acc: 0.8714Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6762 - tversky_loss: 4.3006 - dice_coef: 0.7990 - acc: 0.7555
# Epoch 00040: val_acc did not improve from 0.76882
# 18/18 [==============================] - 20s 1s/step - loss: 0.3532 - tversky_loss: 4.1894 - dice_coef: 0.8973 - acc: 0.8728 - val_loss: 0.8114 - val_tversky_loss: 4.3006 - val_dice_coef: 0.7990 - val_acc: 0.7555
# Epoch 41/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3645 - tversky_loss: 4.1937 - dice_coef: 0.8933 - acc: 0.8677Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6955 - tversky_loss: 4.2305 - dice_coef: 0.8418 - acc: 0.8125
# Epoch 00041: val_acc improved from 0.76882 to 0.81248, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.3634 - tversky_loss: 4.1935 - dice_coef: 0.8936 - acc: 0.8678 - val_loss: 0.8346 - val_tversky_loss: 4.2305 - val_dice_coef: 0.8418 - val_acc: 0.8125
# Epoch 42/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3623 - tversky_loss: 4.1892 - dice_coef: 0.8959 - acc: 0.8720Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7106 - tversky_loss: 4.2768 - dice_coef: 0.8102 - acc: 0.7778
# Epoch 00042: val_acc did not improve from 0.81248
# 18/18 [==============================] - 20s 1s/step - loss: 0.3718 - tversky_loss: 4.1922 - dice_coef: 0.8931 - acc: 0.8682 - val_loss: 0.8527 - val_tversky_loss: 4.2768 - val_dice_coef: 0.8102 - val_acc: 0.7778
# Epoch 43/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3637 - tversky_loss: 4.1964 - dice_coef: 0.8928 - acc: 0.8672Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5683 - tversky_loss: 4.2383 - dice_coef: 0.8441 - acc: 0.8128
# Epoch 00043: val_acc improved from 0.81248 to 0.81278, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.3685 - tversky_loss: 4.1978 - dice_coef: 0.8915 - acc: 0.8650 - val_loss: 0.6820 - val_tversky_loss: 4.2383 - val_dice_coef: 0.8441 - val_acc: 0.8128
# Epoch 44/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3630 - tversky_loss: 4.1894 - dice_coef: 0.8943 - acc: 0.8678Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.8344 - tversky_loss: 4.3377 - dice_coef: 0.7587 - acc: 0.7197
# Epoch 00044: val_acc did not improve from 0.81278
# 18/18 [==============================] - 20s 1s/step - loss: 0.3624 - tversky_loss: 4.1893 - dice_coef: 0.8944 - acc: 0.8674 - val_loss: 1.0012 - val_tversky_loss: 4.3377 - val_dice_coef: 0.7587 - val_acc: 0.7197
# Epoch 45/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3389 - tversky_loss: 4.1838 - dice_coef: 0.9024 - acc: 0.8804Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6866 - tversky_loss: 4.2682 - dice_coef: 0.8107 - acc: 0.7775
# Epoch 00045: val_acc did not improve from 0.81278
# 18/18 [==============================] - 20s 1s/step - loss: 0.3356 - tversky_loss: 4.1824 - dice_coef: 0.9033 - acc: 0.8815 - val_loss: 0.8239 - val_tversky_loss: 4.2682 - val_dice_coef: 0.8107 - val_acc: 0.7775
# Epoch 46/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3123 - tversky_loss: 4.1669 - dice_coef: 0.9107 - acc: 0.8884Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5862 - tversky_loss: 4.2111 - dice_coef: 0.8533 - acc: 0.8223
# Epoch 00046: val_acc improved from 0.81278 to 0.82226, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.3105 - tversky_loss: 4.1663 - dice_coef: 0.9112 - acc: 0.8889 - val_loss: 0.7034 - val_tversky_loss: 4.2111 - val_dice_coef: 0.8533 - val_acc: 0.8223
# Epoch 47/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.3387 - tversky_loss: 4.1771 - dice_coef: 0.9031 - acc: 0.8799Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6505 - tversky_loss: 4.2837 - dice_coef: 0.8087 - acc: 0.7678
# Epoch 00047: val_acc did not improve from 0.82226
# 18/18 [==============================] - 20s 1s/step - loss: 0.3389 - tversky_loss: 4.1775 - dice_coef: 0.9028 - acc: 0.8791 - val_loss: 0.7805 - val_tversky_loss: 4.2837 - val_dice_coef: 0.8087 - val_acc: 0.7678
# Epoch 48/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2978 - tversky_loss: 4.1598 - dice_coef: 0.9153 - acc: 0.8941Epoch 1/100
#  3/18 [====>.........................] - ETA: 7s - loss: 0.5362 - tversky_loss: 4.2119 - dice_coef: 0.8530 - acc: 0.8193
# Epoch 00048: val_acc did not improve from 0.82226
# 18/18 [==============================] - 20s 1s/step - loss: 0.2960 - tversky_loss: 4.1590 - dice_coef: 0.9158 - acc: 0.8947 - val_loss: 0.6435 - val_tversky_loss: 4.2119 - val_dice_coef: 0.8530 - val_acc: 0.8193
# Epoch 49/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2807 - tversky_loss: 4.1510 - dice_coef: 0.9199 - acc: 0.8990Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.1927 - tversky_loss: 4.3750 - dice_coef: 0.6977 - acc: 0.6610
# Epoch 00049: val_acc did not improve from 0.82226
# 18/18 [==============================] - 20s 1s/step - loss: 0.2828 - tversky_loss: 4.1519 - dice_coef: 0.9191 - acc: 0.8978 - val_loss: 1.4312 - val_tversky_loss: 4.3750 - val_dice_coef: 0.6977 - val_acc: 0.6610
# Epoch 50/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2597 - tversky_loss: 4.1410 - dice_coef: 0.9265 - acc: 0.9070Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6513 - tversky_loss: 4.2541 - dice_coef: 0.8223 - acc: 0.7891
# Epoch 00050: val_acc did not improve from 0.82226
# 18/18 [==============================] - 20s 1s/step - loss: 0.2574 - tversky_loss: 4.1403 - dice_coef: 0.9272 - acc: 0.9078 - val_loss: 0.7816 - val_tversky_loss: 4.2541 - val_dice_coef: 0.8223 - val_acc: 0.7891
# Epoch 51/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2346 - tversky_loss: 4.1277 - dice_coef: 0.9341 - acc: 0.9168Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6341 - tversky_loss: 4.2667 - dice_coef: 0.8139 - acc: 0.7733
# Epoch 00051: val_acc did not improve from 0.82226
# 18/18 [==============================] - 20s 1s/step - loss: 0.2352 - tversky_loss: 4.1275 - dice_coef: 0.9341 - acc: 0.9168 - val_loss: 0.7609 - val_tversky_loss: 4.2667 - val_dice_coef: 0.8139 - val_acc: 0.7733
# Epoch 52/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2606 - tversky_loss: 4.1388 - dice_coef: 0.9266 - acc: 0.9083Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5948 - tversky_loss: 4.1964 - dice_coef: 0.8642 - acc: 0.8383
# Epoch 00052: val_acc improved from 0.82226 to 0.83833, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.2624 - tversky_loss: 4.1392 - dice_coef: 0.9260 - acc: 0.9076 - val_loss: 0.7137 - val_tversky_loss: 4.1964 - val_dice_coef: 0.8642 - val_acc: 0.8383
# Epoch 53/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2868 - tversky_loss: 4.1490 - dice_coef: 0.9187 - acc: 0.8979Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5898 - tversky_loss: 4.2168 - dice_coef: 0.8490 - acc: 0.8201
# Epoch 00053: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2839 - tversky_loss: 4.1480 - dice_coef: 0.9195 - acc: 0.8989 - val_loss: 0.7078 - val_tversky_loss: 4.2168 - val_dice_coef: 0.8490 - val_acc: 0.8201
# Epoch 54/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2779 - tversky_loss: 4.1472 - dice_coef: 0.9214 - acc: 0.9012Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7630 - tversky_loss: 4.2110 - dice_coef: 0.8448 - acc: 0.8170
# Epoch 00054: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2762 - tversky_loss: 4.1469 - dice_coef: 0.9218 - acc: 0.9018 - val_loss: 0.9156 - val_tversky_loss: 4.2110 - val_dice_coef: 0.8448 - val_acc: 0.8170
# Epoch 55/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2657 - tversky_loss: 4.1431 - dice_coef: 0.9246 - acc: 0.9059Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6786 - tversky_loss: 4.2374 - dice_coef: 0.8333 - acc: 0.8060
# Epoch 00055: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2660 - tversky_loss: 4.1429 - dice_coef: 0.9245 - acc: 0.9059 - val_loss: 0.8144 - val_tversky_loss: 4.2374 - val_dice_coef: 0.8333 - val_acc: 0.8060
# Epoch 56/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2671 - tversky_loss: 4.1416 - dice_coef: 0.9242 - acc: 0.9044Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6999 - tversky_loss: 4.2337 - dice_coef: 0.8270 - acc: 0.7973
# Epoch 00056: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2679 - tversky_loss: 4.1417 - dice_coef: 0.9239 - acc: 0.9041 - val_loss: 0.8399 - val_tversky_loss: 4.2337 - val_dice_coef: 0.8270 - val_acc: 0.7973
# Epoch 57/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2787 - tversky_loss: 4.1469 - dice_coef: 0.9202 - acc: 0.8996Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.9791 - tversky_loss: 4.2975 - dice_coef: 0.7794 - acc: 0.7426
# Epoch 00057: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2747 - tversky_loss: 4.1453 - dice_coef: 0.9215 - acc: 0.9012 - val_loss: 1.1749 - val_tversky_loss: 4.2975 - val_dice_coef: 0.7794 - val_acc: 0.7426
# Epoch 58/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2436 - tversky_loss: 4.1332 - dice_coef: 0.9313 - acc: 0.9137Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.9665 - tversky_loss: 4.2552 - dice_coef: 0.8020 - acc: 0.7719
# Epoch 00058: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2513 - tversky_loss: 4.1351 - dice_coef: 0.9294 - acc: 0.9113 - val_loss: 1.1598 - val_tversky_loss: 4.2552 - val_dice_coef: 0.8020 - val_acc: 0.7719
# Epoch 59/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2305 - tversky_loss: 4.1266 - dice_coef: 0.9348 - acc: 0.9173Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.9724 - tversky_loss: 4.2501 - dice_coef: 0.8046 - acc: 0.7762
# Epoch 00059: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2293 - tversky_loss: 4.1260 - dice_coef: 0.9354 - acc: 0.9181 - val_loss: 1.1669 - val_tversky_loss: 4.2501 - val_dice_coef: 0.8046 - val_acc: 0.7762
# Epoch 60/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2199 - tversky_loss: 4.1198 - dice_coef: 0.9382 - acc: 0.9220Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7225 - tversky_loss: 4.2460 - dice_coef: 0.8220 - acc: 0.7949
# Epoch 00060: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2212 - tversky_loss: 4.1201 - dice_coef: 0.9378 - acc: 0.9213 - val_loss: 0.8670 - val_tversky_loss: 4.2460 - val_dice_coef: 0.8220 - val_acc: 0.7949
# Epoch 61/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2017 - tversky_loss: 4.1102 - dice_coef: 0.9438 - acc: 0.9285Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6210 - tversky_loss: 4.1955 - dice_coef: 0.8563 - acc: 0.8289
# Epoch 00061: val_acc did not improve from 0.83833
# 18/18 [==============================] - 20s 1s/step - loss: 0.2024 - tversky_loss: 4.1104 - dice_coef: 0.9435 - acc: 0.9282 - val_loss: 0.7452 - val_tversky_loss: 4.1955 - val_dice_coef: 0.8563 - val_acc: 0.8289
# Epoch 62/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.2075 - tversky_loss: 4.1124 - dice_coef: 0.9414 - acc: 0.9251Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.9128 - tversky_loss: 4.3214 - dice_coef: 0.7541 - acc: 0.7104
# Epoch 00062: val_acc did not improve from 0.83833
# 18/18 [==============================] - 19s 1s/step - loss: 0.2063 - tversky_loss: 4.1121 - dice_coef: 0.9417 - acc: 0.9256 - val_loss: 1.0954 - val_tversky_loss: 4.3214 - val_dice_coef: 0.7541 - val_acc: 0.7104
# Epoch 63/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1993 - tversky_loss: 4.1078 - dice_coef: 0.9441 - acc: 0.9284Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5579 - tversky_loss: 4.1887 - dice_coef: 0.8646 - acc: 0.8390
# Epoch 00063: val_acc improved from 0.83833 to 0.83904, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.1984 - tversky_loss: 4.1077 - dice_coef: 0.9441 - acc: 0.9282 - val_loss: 0.6695 - val_tversky_loss: 4.1887 - val_dice_coef: 0.8646 - val_acc: 0.8390
# Epoch 64/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1847 - tversky_loss: 4.1019 - dice_coef: 0.9484 - acc: 0.9335Epoch 1/100
#  3/18 [====>.........................] - ETA: 7s - loss: 0.7235 - tversky_loss: 4.2469 - dice_coef: 0.8193 - acc: 0.7887
# Epoch 00064: val_acc did not improve from 0.83904
# 18/18 [==============================] - 20s 1s/step - loss: 0.1862 - tversky_loss: 4.1022 - dice_coef: 0.9480 - acc: 0.9331 - val_loss: 0.8682 - val_tversky_loss: 4.2469 - val_dice_coef: 0.8193 - val_acc: 0.7887
# Epoch 65/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1861 - tversky_loss: 4.1022 - dice_coef: 0.9479 - acc: 0.9331Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6658 - tversky_loss: 4.2047 - dice_coef: 0.8470 - acc: 0.8197
# Epoch 00065: val_acc did not improve from 0.83904
# 18/18 [==============================] - 20s 1s/step - loss: 0.1867 - tversky_loss: 4.1025 - dice_coef: 0.9477 - acc: 0.9327 - val_loss: 0.7989 - val_tversky_loss: 4.2047 - val_dice_coef: 0.8470 - val_acc: 0.8197
# Epoch 66/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1655 - tversky_loss: 4.0928 - dice_coef: 0.9540 - acc: 0.9406Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6312 - tversky_loss: 4.2015 - dice_coef: 0.8499 - acc: 0.8231
# Epoch 00066: val_acc did not improve from 0.83904
# 18/18 [==============================] - 20s 1s/step - loss: 0.1657 - tversky_loss: 4.0928 - dice_coef: 0.9540 - acc: 0.9405 - val_loss: 0.7575 - val_tversky_loss: 4.2015 - val_dice_coef: 0.8499 - val_acc: 0.8231
# Epoch 67/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1743 - tversky_loss: 4.0946 - dice_coef: 0.9515 - acc: 0.9378Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5339 - tversky_loss: 4.1964 - dice_coef: 0.8620 - acc: 0.8352
# Epoch 00067: val_acc did not improve from 0.83904
# 18/18 [==============================] - 20s 1s/step - loss: 0.1763 - tversky_loss: 4.0957 - dice_coef: 0.9508 - acc: 0.9368 - val_loss: 0.6407 - val_tversky_loss: 4.1964 - val_dice_coef: 0.8620 - val_acc: 0.8352
# Epoch 68/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1608 - tversky_loss: 4.0890 - dice_coef: 0.9555 - acc: 0.9429Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5804 - tversky_loss: 4.1815 - dice_coef: 0.8688 - acc: 0.8463
# Epoch 00068: val_acc improved from 0.83904 to 0.84629, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.1608 - tversky_loss: 4.0888 - dice_coef: 0.9555 - acc: 0.9429 - val_loss: 0.6965 - val_tversky_loss: 4.1815 - val_dice_coef: 0.8688 - val_acc: 0.8463
# Epoch 69/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1587 - tversky_loss: 4.0876 - dice_coef: 0.9559 - acc: 0.9433Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5521 - tversky_loss: 4.1825 - dice_coef: 0.8661 - acc: 0.8406
# Epoch 00069: val_acc did not improve from 0.84629
# 18/18 [==============================] - 20s 1s/step - loss: 0.1606 - tversky_loss: 4.0886 - dice_coef: 0.9553 - acc: 0.9425 - val_loss: 0.6625 - val_tversky_loss: 4.1825 - val_dice_coef: 0.8661 - val_acc: 0.8406
# Epoch 70/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1560 - tversky_loss: 4.0866 - dice_coef: 0.9563 - acc: 0.9431Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5458 - tversky_loss: 4.1813 - dice_coef: 0.8705 - acc: 0.8467
# Epoch 00070: val_acc improved from 0.84629 to 0.84671, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.1554 - tversky_loss: 4.0863 - dice_coef: 0.9565 - acc: 0.9432 - val_loss: 0.6550 - val_tversky_loss: 4.1813 - val_dice_coef: 0.8705 - val_acc: 0.8467
# Epoch 71/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1474 - tversky_loss: 4.0817 - dice_coef: 0.9589 - acc: 0.9467Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6557 - tversky_loss: 4.2082 - dice_coef: 0.8443 - acc: 0.8182
# Epoch 00071: val_acc did not improve from 0.84671
# 18/18 [==============================] - 20s 1s/step - loss: 0.1461 - tversky_loss: 4.0811 - dice_coef: 0.9592 - acc: 0.9471 - val_loss: 0.7868 - val_tversky_loss: 4.2082 - val_dice_coef: 0.8443 - val_acc: 0.8182
# Epoch 72/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1398 - tversky_loss: 4.0775 - dice_coef: 0.9611 - acc: 0.9495Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6457 - tversky_loss: 4.2155 - dice_coef: 0.8430 - acc: 0.8173
# Epoch 00072: val_acc did not improve from 0.84671
# 18/18 [==============================] - 20s 1s/step - loss: 0.1404 - tversky_loss: 4.0779 - dice_coef: 0.9610 - acc: 0.9494 - val_loss: 0.7748 - val_tversky_loss: 4.2155 - val_dice_coef: 0.8430 - val_acc: 0.8173
# Epoch 73/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1459 - tversky_loss: 4.0804 - dice_coef: 0.9592 - acc: 0.9472Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5414 - tversky_loss: 4.1754 - dice_coef: 0.8707 - acc: 0.8473
# Epoch 00073: val_acc improved from 0.84671 to 0.84732, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.1454 - tversky_loss: 4.0802 - dice_coef: 0.9593 - acc: 0.9473 - val_loss: 0.6497 - val_tversky_loss: 4.1754 - val_dice_coef: 0.8707 - val_acc: 0.8473
# Epoch 74/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1390 - tversky_loss: 4.0768 - dice_coef: 0.9614 - acc: 0.9500Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6162 - tversky_loss: 4.1934 - dice_coef: 0.8549 - acc: 0.8288
# Epoch 00074: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1410 - tversky_loss: 4.0776 - dice_coef: 0.9609 - acc: 0.9493 - val_loss: 0.7395 - val_tversky_loss: 4.1934 - val_dice_coef: 0.8549 - val_acc: 0.8288
# Epoch 75/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1451 - tversky_loss: 4.0801 - dice_coef: 0.9595 - acc: 0.9475Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7548 - tversky_loss: 4.1985 - dice_coef: 0.8423 - acc: 0.8168
# Epoch 00075: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1445 - tversky_loss: 4.0798 - dice_coef: 0.9597 - acc: 0.9478 - val_loss: 0.9058 - val_tversky_loss: 4.1985 - val_dice_coef: 0.8423 - val_acc: 0.8168
# Epoch 76/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1502 - tversky_loss: 4.0805 - dice_coef: 0.9584 - acc: 0.9465Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.4026 - tversky_loss: 4.3339 - dice_coef: 0.7157 - acc: 0.6862
# Epoch 00076: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1508 - tversky_loss: 4.0808 - dice_coef: 0.9582 - acc: 0.9463 - val_loss: 1.6831 - val_tversky_loss: 4.3339 - val_dice_coef: 0.7157 - val_acc: 0.6862
# Epoch 77/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1506 - tversky_loss: 4.0838 - dice_coef: 0.9578 - acc: 0.9454Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.4822 - tversky_loss: 4.3859 - dice_coef: 0.6624 - acc: 0.6254
# Epoch 00077: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1493 - tversky_loss: 4.0831 - dice_coef: 0.9581 - acc: 0.9459 - val_loss: 1.7786 - val_tversky_loss: 4.3859 - val_dice_coef: 0.6624 - val_acc: 0.6254
# Epoch 78/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1367 - tversky_loss: 4.0763 - dice_coef: 0.9618 - acc: 0.9506Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7599 - tversky_loss: 4.2356 - dice_coef: 0.8221 - acc: 0.7936
# Epoch 00078: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1372 - tversky_loss: 4.0765 - dice_coef: 0.9617 - acc: 0.9504 - val_loss: 0.9119 - val_tversky_loss: 4.2356 - val_dice_coef: 0.8221 - val_acc: 0.7936
# Epoch 79/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1345 - tversky_loss: 4.0739 - dice_coef: 0.9625 - acc: 0.9514Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7667 - tversky_loss: 4.2309 - dice_coef: 0.8256 - acc: 0.7989
# Epoch 00079: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1330 - tversky_loss: 4.0734 - dice_coef: 0.9629 - acc: 0.9519 - val_loss: 0.9200 - val_tversky_loss: 4.2309 - val_dice_coef: 0.8256 - val_acc: 0.7989
# Epoch 80/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1441 - tversky_loss: 4.0783 - dice_coef: 0.9595 - acc: 0.9476Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7271 - tversky_loss: 4.2146 - dice_coef: 0.8361 - acc: 0.8117
# Epoch 00080: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1429 - tversky_loss: 4.0777 - dice_coef: 0.9599 - acc: 0.9480 - val_loss: 0.8725 - val_tversky_loss: 4.2146 - val_dice_coef: 0.8361 - val_acc: 0.8117
# Epoch 81/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1266 - tversky_loss: 4.0712 - dice_coef: 0.9647 - acc: 0.9538Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7231 - tversky_loss: 4.2229 - dice_coef: 0.8316 - acc: 0.8035
# Epoch 00081: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1271 - tversky_loss: 4.0714 - dice_coef: 0.9646 - acc: 0.9537 - val_loss: 0.8677 - val_tversky_loss: 4.2229 - val_dice_coef: 0.8316 - val_acc: 0.8035
# Epoch 82/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1197 - tversky_loss: 4.0678 - dice_coef: 0.9667 - acc: 0.9566Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7222 - tversky_loss: 4.2196 - dice_coef: 0.8346 - acc: 0.8118
# Epoch 00082: val_acc did not improve from 0.84732
# 18/18 [==============================] - 19s 1s/step - loss: 0.1194 - tversky_loss: 4.0676 - dice_coef: 0.9667 - acc: 0.9567 - val_loss: 0.8667 - val_tversky_loss: 4.2196 - val_dice_coef: 0.8346 - val_acc: 0.8118
# Epoch 83/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1187 - tversky_loss: 4.0663 - dice_coef: 0.9671 - acc: 0.9573Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6458 - tversky_loss: 4.1840 - dice_coef: 0.8585 - acc: 0.8353
# Epoch 00083: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1182 - tversky_loss: 4.0661 - dice_coef: 0.9672 - acc: 0.9574 - val_loss: 0.7749 - val_tversky_loss: 4.1840 - val_dice_coef: 0.8585 - val_acc: 0.8353
# Epoch 84/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1101 - tversky_loss: 4.0618 - dice_coef: 0.9693 - acc: 0.9597Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7168 - tversky_loss: 4.2188 - dice_coef: 0.8354 - acc: 0.8097
# Epoch 00084: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1096 - tversky_loss: 4.0616 - dice_coef: 0.9694 - acc: 0.9599 - val_loss: 0.8602 - val_tversky_loss: 4.2188 - val_dice_coef: 0.8354 - val_acc: 0.8097
# Epoch 85/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1082 - tversky_loss: 4.0614 - dice_coef: 0.9698 - acc: 0.9603Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6722 - tversky_loss: 4.2033 - dice_coef: 0.8461 - acc: 0.8217
# Epoch 00085: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1080 - tversky_loss: 4.0613 - dice_coef: 0.9698 - acc: 0.9604 - val_loss: 0.8066 - val_tversky_loss: 4.2033 - val_dice_coef: 0.8461 - val_acc: 0.8217
# Epoch 86/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1095 - tversky_loss: 4.0612 - dice_coef: 0.9696 - acc: 0.9605Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6818 - tversky_loss: 4.1940 - dice_coef: 0.8500 - acc: 0.8259
# Epoch 00086: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1089 - tversky_loss: 4.0608 - dice_coef: 0.9698 - acc: 0.9607 - val_loss: 0.8181 - val_tversky_loss: 4.1940 - val_dice_coef: 0.8500 - val_acc: 0.8259
# Epoch 87/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.1042 - tversky_loss: 4.0593 - dice_coef: 0.9712 - acc: 0.9626Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 1.2110 - tversky_loss: 4.2259 - dice_coef: 0.8129 - acc: 0.7905
# Epoch 00087: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.1050 - tversky_loss: 4.0596 - dice_coef: 0.9709 - acc: 0.9622 - val_loss: 1.4532 - val_tversky_loss: 4.2259 - val_dice_coef: 0.8129 - val_acc: 0.7905
# Epoch 88/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0992 - tversky_loss: 4.0565 - dice_coef: 0.9723 - acc: 0.9639Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7489 - tversky_loss: 4.1882 - dice_coef: 0.8485 - acc: 0.8273
# Epoch 00088: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.0987 - tversky_loss: 4.0564 - dice_coef: 0.9725 - acc: 0.9641 - val_loss: 0.8987 - val_tversky_loss: 4.1882 - val_dice_coef: 0.8485 - val_acc: 0.8273
# Epoch 89/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0948 - tversky_loss: 4.0537 - dice_coef: 0.9736 - acc: 0.9654Epoch 1/100
#  3/18 [====>.........................] - ETA: 7s - loss: 0.6830 - tversky_loss: 4.1879 - dice_coef: 0.8523 - acc: 0.8282
# Epoch 00089: val_acc did not improve from 0.84732
# 18/18 [==============================] - 20s 1s/step - loss: 0.0947 - tversky_loss: 4.0537 - dice_coef: 0.9736 - acc: 0.9655 - val_loss: 0.8196 - val_tversky_loss: 4.1879 - val_dice_coef: 0.8523 - val_acc: 0.8282
# Epoch 90/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0932 - tversky_loss: 4.0534 - dice_coef: 0.9740 - acc: 0.9659Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.5662 - tversky_loss: 4.1690 - dice_coef: 0.8715 - acc: 0.8481
# Epoch 00090: val_acc improved from 0.84732 to 0.84814, saving model to Unet_guided1_100_epochs_checkpoint.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.0931 - tversky_loss: 4.0534 - dice_coef: 0.9740 - acc: 0.9659 - val_loss: 0.6795 - val_tversky_loss: 4.1690 - val_dice_coef: 0.8715 - val_acc: 0.8481
# Epoch 91/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0887 - tversky_loss: 4.0509 - dice_coef: 0.9752 - acc: 0.9674Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6830 - tversky_loss: 4.1868 - dice_coef: 0.8549 - acc: 0.8321
# Epoch 00091: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0891 - tversky_loss: 4.0511 - dice_coef: 0.9752 - acc: 0.9673 - val_loss: 0.8196 - val_tversky_loss: 4.1868 - val_dice_coef: 0.8549 - val_acc: 0.8321
# Epoch 92/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0882 - tversky_loss: 4.0496 - dice_coef: 0.9757 - acc: 0.9682Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6867 - tversky_loss: 4.1965 - dice_coef: 0.8450 - acc: 0.8190
# Epoch 00092: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0882 - tversky_loss: 4.0496 - dice_coef: 0.9757 - acc: 0.9682 - val_loss: 0.8240 - val_tversky_loss: 4.1965 - val_dice_coef: 0.8450 - val_acc: 0.8190
# Epoch 93/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0833 - tversky_loss: 4.0482 - dice_coef: 0.9768 - acc: 0.9694Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6457 - tversky_loss: 4.1734 - dice_coef: 0.8652 - acc: 0.8440
# Epoch 00093: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0838 - tversky_loss: 4.0484 - dice_coef: 0.9766 - acc: 0.9692 - val_loss: 0.7749 - val_tversky_loss: 4.1734 - val_dice_coef: 0.8652 - val_acc: 0.8440
# Epoch 94/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0867 - tversky_loss: 4.0490 - dice_coef: 0.9760 - acc: 0.9686Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.6834 - tversky_loss: 4.1876 - dice_coef: 0.8523 - acc: 0.8292
# Epoch 00094: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0859 - tversky_loss: 4.0487 - dice_coef: 0.9762 - acc: 0.9689 - val_loss: 0.8201 - val_tversky_loss: 4.1876 - val_dice_coef: 0.8523 - val_acc: 0.8292
# Epoch 95/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0861 - tversky_loss: 4.0486 - dice_coef: 0.9763 - acc: 0.9690Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7938 - tversky_loss: 4.1878 - dice_coef: 0.8470 - acc: 0.8255
# Epoch 00095: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0859 - tversky_loss: 4.0486 - dice_coef: 0.9764 - acc: 0.9691 - val_loss: 0.9526 - val_tversky_loss: 4.1878 - val_dice_coef: 0.8470 - val_acc: 0.8255
# Epoch 96/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0803 - tversky_loss: 4.0455 - dice_coef: 0.9778 - acc: 0.9709Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7440 - tversky_loss: 4.1838 - dice_coef: 0.8517 - acc: 0.8305
# Epoch 00096: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0798 - tversky_loss: 4.0451 - dice_coef: 0.9779 - acc: 0.9711 - val_loss: 0.8928 - val_tversky_loss: 4.1838 - val_dice_coef: 0.8517 - val_acc: 0.8305
# Epoch 97/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0840 - tversky_loss: 4.0472 - dice_coef: 0.9768 - acc: 0.9698Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7692 - tversky_loss: 4.1851 - dice_coef: 0.8485 - acc: 0.8266
# Epoch 00097: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0839 - tversky_loss: 4.0472 - dice_coef: 0.9768 - acc: 0.9697 - val_loss: 0.9230 - val_tversky_loss: 4.1851 - val_dice_coef: 0.8485 - val_acc: 0.8266
# Epoch 98/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0767 - tversky_loss: 4.0440 - dice_coef: 0.9789 - acc: 0.9724Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7501 - tversky_loss: 4.1690 - dice_coef: 0.8611 - acc: 0.8429
# Epoch 00098: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0765 - tversky_loss: 4.0439 - dice_coef: 0.9789 - acc: 0.9724 - val_loss: 0.9001 - val_tversky_loss: 4.1690 - val_dice_coef: 0.8611 - val_acc: 0.8429
# Epoch 99/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0715 - tversky_loss: 4.0412 - dice_coef: 0.9801 - acc: 0.9739Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7586 - tversky_loss: 4.1842 - dice_coef: 0.8478 - acc: 0.8269
# Epoch 00099: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0715 - tversky_loss: 4.0412 - dice_coef: 0.9801 - acc: 0.9739 - val_loss: 0.9103 - val_tversky_loss: 4.1842 - val_dice_coef: 0.8478 - val_acc: 0.8269
# Epoch 100/100
# 17/18 [===========================>..] - ETA: 1s - loss: 0.0676 - tversky_loss: 4.0393 - dice_coef: 0.9813 - acc: 0.9756Epoch 1/100
#  3/18 [====>.........................] - ETA: 6s - loss: 0.7435 - tversky_loss: 4.1816 - dice_coef: 0.8513 - acc: 0.8315
# Epoch 00100: val_acc did not improve from 0.84814
# 18/18 [==============================] - 20s 1s/step - loss: 0.0681 - tversky_loss: 4.0394 - dice_coef: 0.9812 - acc: 0.9754 - val_loss: 0.8923 - val_tversky_loss: 4.1816 - val_dice_coef: 0.8513 - val_acc: 0.8315

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Model evaluation historical plots

# %%
#Load the checkpoint model with best accuracy
model.load_weights("/content/Unet_guided1_100_epochs_checkpoint.h5")

# %%
# Get actual number of epochs model was trained for
N = len(result.history['loss'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("Training Loss")
plt.plot(np.arange(0, N), result.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), result.history["val_loss"], label="val_loss")
plt.ylim(0, 1)

fig.add_subplot(1,2,2)
plt.title("Training Accuracy")
plt.plot(np.arange(0, N), result.history["acc"], label="train_accuracy")
plt.plot(np.arange(0, N), result.history["val_acc"], label="val_accuracy")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# ### Extract and display model frame, prediction and mask batch

# %%
import cv2
testing_gen = ValAugmentGenerator()
batch_img,batch_mask = next(testing_gen)
pred_all= model.predict(batch_img)
np.shape(pred_all)
# Out:
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# (16, 256, 256, 5)

# %%
for i in range(0,np.shape(pred_all)[0]):
    
    fig = plt.figure(figsize=(20,8))
    
    ax1 = fig.add_subplot(1,3,1)
    ax1.imshow(batch_img[i])
    ax1.title.set_text('Actual frame')
    ax1.grid(b=None)
    
    
    ax2 = fig.add_subplot(1,3,2)
    ax2.set_title('Ground truth labels')
    ax2.imshow(onehot_to_rgb(batch_mask[i],id2code))
    ax2.grid(b=None)
    
    ax3 = fig.add_subplot(1,3,3)
    ax3.set_title('Predicted labels')
    predicted_image = onehot_to_rgb(pred_all[i],id2code)
    predicted_image_dir = os.path.join("/content/gdrive/My Drive/BBM419_Final/predictions_Unet", "predicted_" + str(i) + ".png")
    if not os.path.exists(predicted_image_dir):
      cv2.imwrite(predicted_image_dir, predicted_image)
    ax3.imshow(predicted_image)
    ax3.grid(b=None)
    
    plt.show()
