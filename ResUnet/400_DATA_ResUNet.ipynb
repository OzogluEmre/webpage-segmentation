# %% [markdown]
# # WEBPAGE SEGMENTATION WITH RESUNET

# %% [markdown]
# ## Importing libraries

# %%
# %pip install tensorflow==1.15.0
# Out:
# Requirement already satisfied: tensorflow==1.15.0 in /usr/local/lib/python3.6/dist-packages (1.15.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (3.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.2.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.30.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.12.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.18.5)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.15.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.34.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (3.2.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0) (0.9.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15.0) (47.3.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.0) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (1.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.1.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
from PIL import Image

# from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *


#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
from tensorflow.compat.v1.layers import conv2d_transpose
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
os.environ['DISABLE_COLAB_TF_IMPORT_HOOK'] = '1'
tf.enable_eager_execution()

# %% [markdown]
# # Environment checks

# %%
print(tf.__version__)
x = tf.random.uniform([3, 3])

print("Is there a GPU available: "),
print(tf.test.is_gpu_available())

print("Is the Tensor on GPU #0:  "),
print(x.device.endswith('GPU:0'))

print("Device name: {}".format((x.device)))

print(tf.executing_eagerly())
# Out:
# 1.15.0
# Is there a GPU available:
# True
# Is the Tensor on GPU #0:
# True
# Device name: /job:localhost/replica:0/task:0/device:GPU:0
# True

# %% [markdown]
# ## Data preparation - Importing, Cleaning and Creating structured directory

# %% [markdown]
# ### Function to import and process frames and masks as tensors

# %%
def _read_to_tensor(fname, output_height=256, output_width=256, normalize_data=False):
    '''Function to read images from given image file path, and provide resized images as tensors
        Inputs: 
            fname - image file path
            output_height - required output image height
            output_width - required output image width
            normalize_data - if True, normalize data to be centered around 0 (mean 0, range 0 to 1)
        Output: Processed image tensors
    '''
    
    # Read the image as a tensor
    img_strings = tf.io.read_file(fname)
    imgs_decoded = tf.image.decode_jpeg(img_strings)
    
    # Resize the image
    output = tf.image.resize(imgs_decoded, [output_height, output_width])
    
    # Normalize if required
    if normalize_data:
        output = (output - 128) / 128
    return output

# %% [markdown]
# ### Image directory and size parameters

# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img_dir = '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/'

# Required image dimensions
output_height = 256
output_width = 256

# %% [markdown]
# ### Reading frames and masks
# - Mask file names end in "\_L.png"

# %%
def read_images(img_dir):
    '''Function to get all image directories, read images and masks in separate tensors
        Inputs: 
            img_dir - file directory
        Outputs 
            frame_tensors, masks_tensors, frame files list, mask files list
    '''
    
    # Get the file names list from provided directory
    file_list = [f for f in os.listdir(img_dir) if os.path.isfile(os.path.join(img_dir, f))]
    
    # Separate frame and mask files lists, exclude unnecessary files
    frames_list = [file for file in file_list if ('_L' not in file) and ('txt' not in file)]
    masks_list = [file for file in file_list if ('_L' in file) and ('txt' not in file)]
    frames_list.sort()
    masks_list.sort()
    print('{} frame files found in the provided directory.'.format(len(frames_list)))
    print('{} mask files found in the provided directory.'.format(len(masks_list)))
    
    # Create file paths from file names
    frames_paths = [os.path.join(img_dir, fname) for fname in frames_list]
    masks_paths = [os.path.join(img_dir, fname) for fname in masks_list]
    
    # Create dataset of tensors
    frame_data = tf.data.Dataset.from_tensor_slices(frames_paths)
    masks_data = tf.data.Dataset.from_tensor_slices(masks_paths)
    
    # Read images into the tensor dataset
    frame_tensors = frame_data.map(_read_to_tensor)
    masks_tensors = masks_data.map(_read_to_tensor)
    
    print('Completed importing {} frame images from the provided directory.'.format(len(frames_list)))
    print('Completed importing {} mask images from the provided directory.'.format(len(masks_list)))
    
    return frame_tensors, masks_tensors, frames_list, masks_list

frame_tensors, masks_tensors, frames_list, masks_list = read_images(img_dir)
# Out:
# 400 frame files found in the provided directory.
# 400 mask files found in the provided directory.
# Completed importing 400 frame images from the provided directory.
# Completed importing 400 mask images from the provided directory.

# %%
# Make an iterator to extract images from the tensor dataset
frame_batches = tf.compat.v1.data.make_one_shot_iterator(frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks_tensors)


n_images_to_show = 5

for i in range(n_images_to_show):
    
    # Get the next image from iterator
    frame = frame_batches.next().numpy().astype(np.uint8)
    mask = mask_batches.next().numpy().astype(np.uint8)
    
    #Plot the corresponding frames and masks
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.imshow(frame)
    fig.add_subplot(1,2,2)
    plt.imshow(mask)
    plt.show()

# %% [markdown]
# ### Creating folder structure common for Computer Vision problems

# %%
DATA_PATH = '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_1_MERGED/'

# Create folders to hold images and masks

folders = ['train_frames/train', 'train_masks/train', 'val_frames/val', 'val_masks/val']


for folder in folders:
    try:
        os.makedirs(DATA_PATH + folder)
    except Exception as e: print(e)
# Out:
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_3_MERGED/train_frames/train'
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_3_MERGED/train_masks/train'
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_3_MERGED/val_frames/val'
# [Errno 17] File exists: '/content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/DATA_END_OF_UNI/GUIDED_3_MERGED/val_masks/val'

# %% [markdown]
# ### Saving frames and masks to correct directories

# %%
def generate_image_folder_structure(frames, masks, frames_list, masks_list):
    '''Function to save images in the appropriate folder directories 
        Inputs: 
            frames - frame tensor dataset
            masks - mask tensor dataset
            frames_list - frame file paths
            masks_list - mask file paths
    '''
    #Create iterators for frames and masks
    frame_batches = tf.compat.v1.data.make_one_shot_iterator(frames)  # outside of TF Eager, we would use make_one_shot_iterator
    mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks)
    
    #Iterate over the train images while saving the frames and masks in appropriate folders
    dir_name='train'
    for file in zip(frames_list[:-round(0.2*len(frames_list))],masks_list[:-round(0.2*len(masks_list))]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    #Iterate over the val images while saving the frames and masks in appropriate folders
    dir_name='val'
    for file in zip(frames_list[-round(0.2*len(frames_list)):],masks_list[-round(0.2*len(masks_list)):]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    print("Saved {} frames to directory {}".format(len(frames_list),DATA_PATH))
    print("Saved {} masks to directory {}".format(len(masks_list),DATA_PATH))
    
generate_image_folder_structure(frame_tensors, masks_tensors, frames_list, masks_list)

#generate_image_folder_structure(train_frames, train_masks, val_files, 'val')
# Out:
# Saved 197 frames to directory /content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/GUIDED_1/
# Saved 197 masks to directory /content/gdrive/My Drive/BBM419_Final/WITH_PIXEL_CORRECTION/GUIDED_1/

# %% [markdown]
# ## Extract Target Class definitions

# %% [markdown]
# ### Function to parse the file "label_colors.txt" which contains the class definitions

# %%
def parse_code(l):
    '''Function to parse lines in a text file, returns separated elements (label codes and names in this case)
    '''
    if len(l.strip().split("\t")) == 2:
        a, b = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), b
    else:
        a, b, c = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), c

# %% [markdown]
# ### Parse and extract label names and codes

# %%
label_codes, label_names = zip(*[parse_code(l) for l in open("/content/label_colors.txt")])
label_codes, label_names = list(label_codes), list(label_names)
label_codes[:5], label_names[:5]
# Out:
# ([(255, 255, 255), (255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 0, 255)],
#  ['Background', 'Image', 'Text', 'FormElement', 'Container'])

# %%
label_codes, label_names
# Out:
# ([(255, 255, 255), (255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 0, 255)],
#  ['Background', 'Image', 'Text', 'FormElement', 'Container'])

# %% [markdown]
# ### Create useful label and code conversion dictionaries
# _These will be used for:_
# - One hot encoding the mask labels for model training
# - Decoding the predicted labels for interpretation and visualization

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}

# %%
name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
id2code
# Out:
# {0: (255, 255, 255),
#  1: (255, 0, 0),
#  2: (0, 255, 0),
#  3: (0, 0, 255),
#  4: (255, 0, 255)}

# %%
id2name
# Out:
# {0: 'Background', 1: 'Image', 2: 'Text', 3: 'FormElement', 4: 'Container'}

# %% [markdown]
# ### Define functions for one hot encoding rgb labels, and decoding encoded predictions

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: 
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    num_classes = len(colormap)
    shape = rgb_image.shape[:2]+(num_classes,)
    encoded_image = np.zeros( shape, dtype=np.int8 )
    for i, cls in enumerate(colormap):
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %% [markdown]
# # Creating custom Image data generators

# %% [markdown]
# ### Defining data generators

# %%
# Normalizing only frame images, since masks contain label info
data_gen_args = dict(rescale=1./255)
mask_gen_args = dict()

train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)

# Seed defined for aligning images and their masks
seed = 1

# %% [markdown]
# ### Custom image data generators for creating batches of frames and masks

# %%
def TrainAugmentGenerator(seed = 1, batch_size = 16):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    train_image_generator = train_frames_datagen.flow_from_directory(
    DATA_PATH + 'train_frames/',
    batch_size = batch_size, seed = seed)

    train_mask_generator = train_masks_datagen.flow_from_directory(
    DATA_PATH + 'train_masks/',
    batch_size = batch_size, seed = seed)

    while True:
        X1i = train_image_generator.next()
        X2i = train_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

def ValAugmentGenerator(seed = 1, batch_size = 16):
    '''Validation Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    val_image_generator = val_frames_datagen.flow_from_directory(
    DATA_PATH + 'val_frames/',
    batch_size = batch_size, seed = seed)


    val_mask_generator = val_masks_datagen.flow_from_directory(
    DATA_PATH + 'val_masks/',
    batch_size = batch_size, seed = seed)


    while True:
        X1i = val_image_generator.next()
        X2i = val_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

# %% [markdown]
# ## Generating ResUnet

# %%
def bn_act(x, act=True):
    x = BatchNormalization()(x)
    if act == True:
        x = Activation("relu")(x)
    return x

def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = bn_act(x)
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv

def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    
    shortcut = Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    
    output = Add()([conv, shortcut])
    return output

def residual_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1)
    
    shortcut = Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    
    output = Add()([shortcut, res])
    return output

def upsample_concat_block(x, xskip):
    u = UpSampling2D((2, 2))(x)
    c = concatenate([u, xskip], axis=3)
    return c

def ResUNet():
    f = [16, 32, 64, 128, 256]
    batch_shape=(256,256,3)
    inputs = Input(batch_shape=(16, 256, 256, 3))
    
    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)
    
    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)
    
    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = Conv2D(5, (1, 1), padding="same", activation="sigmoid")(d4)
    model = Model(inputs, outputs)
    return model

# %%
model = ResUNet()

# %% [markdown]
# ## Defining dice co-efficients for model performance

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %% [markdown]
# ## Compiling model
# - Using categorical crossentropy loss since labels have been one hot encoded

# %%
adam = Adam()
# model.compile(optimizer=adam, loss=dice_coef_loss, metrics=[dice_coef, 'accuracy'])
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=[dice_coef, 'accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(16, 256, 256, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (16, 256, 256, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (16, 256, 256, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (16, 256, 256, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (16, 256, 256, 16)   64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (16, 256, 256, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (16, 256, 256, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (16, 256, 256, 16)   0           conv2d_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (16, 256, 256, 16)   64          add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (16, 256, 256, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (16, 128, 128, 32)   4640        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (16, 128, 128, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (16, 128, 128, 32)   544         add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (16, 128, 128, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (16, 128, 128, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (16, 128, 128, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (16, 128, 128, 32)   0           batch_normalization_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (16, 128, 128, 32)   128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (16, 128, 128, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (16, 64, 64, 64)     18496       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (16, 64, 64, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (16, 64, 64, 64)     2112        add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (16, 64, 64, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (16, 64, 64, 64)     256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (16, 64, 64, 64)     36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (16, 64, 64, 64)     0           batch_normalization_7[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (16, 64, 64, 64)     256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (16, 64, 64, 64)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (16, 32, 32, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (16, 32, 32, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (16, 32, 32, 128)    8320        add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (16, 32, 32, 128)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (16, 32, 32, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (16, 32, 32, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (16, 32, 32, 128)    0           batch_normalization_10[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (16, 32, 32, 128)    512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (16, 32, 32, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (16, 16, 16, 256)    295168      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (16, 16, 16, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (16, 16, 16, 256)    33024       add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (16, 16, 16, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (16, 16, 16, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (16, 16, 16, 256)    590080      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (16, 16, 16, 256)    0           batch_normalization_13[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (16, 16, 16, 256)    1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (16, 16, 16, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (16, 16, 16, 256)    590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (16, 16, 16, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (16, 16, 16, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (16, 16, 16, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (16, 32, 32, 256)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (16, 32, 32, 384)    0           up_sampling2d[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (16, 32, 32, 384)    1536        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (16, 32, 32, 384)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (16, 32, 32, 256)    884992      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (16, 32, 32, 256)    1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (16, 32, 32, 256)    98560       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (16, 32, 32, 256)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (16, 32, 32, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (16, 32, 32, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (16, 32, 32, 256)    0           batch_normalization_18[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (16, 64, 64, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (16, 64, 64, 320)    0           up_sampling2d_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (16, 64, 64, 320)    1280        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (16, 64, 64, 320)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (16, 64, 64, 128)    368768      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (16, 64, 64, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (16, 64, 64, 128)    41088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (16, 64, 64, 128)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (16, 64, 64, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (16, 64, 64, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (16, 64, 64, 128)    0           batch_normalization_21[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (16, 128, 128, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (16, 128, 128, 160)  0           up_sampling2d_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (16, 128, 128, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (16, 128, 128, 160)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (16, 128, 128, 64)   92224       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (16, 128, 128, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (16, 128, 128, 64)   10304       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (16, 128, 128, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (16, 128, 128, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (16, 128, 128, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (16, 128, 128, 64)   0           batch_normalization_24[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (16, 256, 256, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (16, 256, 256, 80)   0           up_sampling2d_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (16, 256, 256, 80)   320         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (16, 256, 256, 80)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (16, 256, 256, 32)   23072       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (16, 256, 256, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (16, 256, 256, 32)   2592        concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (16, 256, 256, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (16, 256, 256, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (16, 256, 256, 32)   9248        activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (16, 256, 256, 32)   0           batch_normalization_27[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (16, 256, 256, 5)    165         add_8[0][0]
# ==================================================================================================
# Total params: 4,723,189
# Trainable params: 4,715,893
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %% [markdown]
# ## Define model callback settings

# %%
tb = TensorBoard(log_dir='logs', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='RESUNET_Guided_epochs80_checkpoint.h5', monitor='val_acc', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='max', monitor='val_acc', patience=10, verbose=1)
callbacks = [tb, mc]

# %% [markdown]
# ## Train and save the U-Net model

# %%
batch_size = 16
steps_per_epoch = np.ceil(float(len(frames_list) - round(0.1*len(frames_list))) / float(batch_size))
steps_per_epoch = int(steps_per_epoch)

# %%
validation_steps = (float((round(0.1*len(frames_list)))) / float(batch_size))
validation_steps = int(validation_steps)

# %%
num_epochs = 80

# %%
# Train model


result = model.fit_generator(TrainAugmentGenerator(),
                validation_data = ValAugmentGenerator(),
                steps_per_epoch=18,
                validation_steps = validation_steps,
                epochs=num_epochs, use_multiprocessing=True,callbacks=callbacks)
model.save_weights("RESUNET_epochs.h5", overwrite=True)
# Out:
# Epoch 1/80
# Found 320 images belonging to 1 classes.
# Found 320 images belonging to 1 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1394: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 17/18 [===========================>..] - ETA: 10s - loss: 1.0678 - dice_coef: 0.6111 - acc: 0.6046Epoch 1/80
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
#  2/18 [==>...........................] - ETA: 3:16 - loss: 1.6994 - dice_coef: 0.3326 - acc: 0.3922
# Epoch 00001: val_acc improved from -inf to 0.39217, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 216s 12s/step - loss: 1.0522 - dice_coef: 0.6165 - acc: 0.6086 - val_loss: 1.6994 - val_dice_coef: 0.3326 - val_acc: 0.3922
# Epoch 2/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.8239 - dice_coef: 0.7095 - acc: 0.6868Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 6.7667 - dice_coef: 0.2524 - acc: 0.2977
# Epoch 00002: val_acc did not improve from 0.39217
# 18/18 [==============================] - 11s 599ms/step - loss: 0.8181 - dice_coef: 0.7125 - acc: 0.6906 - val_loss: 6.7667 - val_dice_coef: 0.2524 - val_acc: 0.2977
# Epoch 3/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7880 - dice_coef: 0.7317 - acc: 0.6944Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.6245 - dice_coef: 0.3692 - acc: 0.5041
# Epoch 00003: val_acc improved from 0.39217 to 0.50414, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 11s 635ms/step - loss: 0.7905 - dice_coef: 0.7308 - acc: 0.6933 - val_loss: 1.6245 - val_dice_coef: 0.3692 - val_acc: 0.5041
# Epoch 4/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7306 - dice_coef: 0.7587 - acc: 0.7239Epoch 1/80
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 14s - loss: 1.4136 - dice_coef: 0.4407 - acc: 0.3362
# Epoch 00004: val_acc did not improve from 0.50414
# 18/18 [==============================] - 12s 667ms/step - loss: 0.7265 - dice_coef: 0.7603 - acc: 0.7269 - val_loss: 1.4136 - val_dice_coef: 0.4407 - val_acc: 0.3362
# Epoch 5/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6809 - dice_coef: 0.7791 - acc: 0.7475Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 2.0168 - dice_coef: 0.5119 - acc: 0.5361
# Epoch 00005: val_acc improved from 0.50414 to 0.53609, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 17s 967ms/step - loss: 0.6759 - dice_coef: 0.7808 - acc: 0.7493 - val_loss: 2.0168 - val_dice_coef: 0.5119 - val_acc: 0.5361
# Epoch 6/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6844 - dice_coef: 0.7794 - acc: 0.7409Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 2.0464 - dice_coef: 0.5791 - acc: 0.6223
# Epoch 00006: val_acc improved from 0.53609 to 0.62233, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 12s 692ms/step - loss: 0.6811 - dice_coef: 0.7810 - acc: 0.7432 - val_loss: 2.0464 - val_dice_coef: 0.5791 - val_acc: 0.6223
# Epoch 7/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6629 - dice_coef: 0.7908 - acc: 0.7546Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.4782 - dice_coef: 0.6576 - acc: 0.6678
# Epoch 00007: val_acc improved from 0.62233 to 0.66779, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 13s 698ms/step - loss: 0.6546 - dice_coef: 0.7932 - acc: 0.7585 - val_loss: 1.4782 - val_dice_coef: 0.6576 - val_acc: 0.6678
# Epoch 8/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6735 - dice_coef: 0.7716 - acc: 0.7382Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 2.2106 - dice_coef: 0.5910 - acc: 0.5823
# Epoch 00008: val_acc did not improve from 0.66779
# 18/18 [==============================] - 12s 673ms/step - loss: 0.6781 - dice_coef: 0.7709 - acc: 0.7381 - val_loss: 2.2106 - val_dice_coef: 0.5910 - val_acc: 0.5823
# Epoch 9/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6119 - dice_coef: 0.7980 - acc: 0.7699Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.5779 - dice_coef: 0.5858 - acc: 0.5446
# Epoch 00009: val_acc did not improve from 0.66779
# 18/18 [==============================] - 12s 681ms/step - loss: 0.6070 - dice_coef: 0.8000 - acc: 0.7724 - val_loss: 1.5779 - val_dice_coef: 0.5858 - val_acc: 0.5446
# Epoch 10/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6053 - dice_coef: 0.7999 - acc: 0.7739Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.6545 - dice_coef: 0.4362 - acc: 0.4620
# Epoch 00010: val_acc did not improve from 0.66779
# 18/18 [==============================] - 12s 691ms/step - loss: 0.6043 - dice_coef: 0.8002 - acc: 0.7735 - val_loss: 1.6545 - val_dice_coef: 0.4362 - val_acc: 0.4620
# Epoch 11/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5783 - dice_coef: 0.8118 - acc: 0.7855Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.7930 - dice_coef: 0.4988 - acc: 0.4019
# Epoch 00011: val_acc did not improve from 0.66779
# 18/18 [==============================] - 12s 691ms/step - loss: 0.5774 - dice_coef: 0.8121 - acc: 0.7857 - val_loss: 1.7930 - val_dice_coef: 0.4988 - val_acc: 0.4019
# Epoch 12/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6093 - dice_coef: 0.8000 - acc: 0.7688Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.0642 - dice_coef: 0.6926 - acc: 0.6474
# Epoch 00012: val_acc did not improve from 0.66779
# 18/18 [==============================] - 12s 690ms/step - loss: 0.6061 - dice_coef: 0.8010 - acc: 0.7699 - val_loss: 1.0642 - val_dice_coef: 0.6926 - val_acc: 0.6474
# Epoch 13/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5257 - dice_coef: 0.8308 - acc: 0.8074Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.4365 - dice_coef: 0.6635 - acc: 0.6274
# Epoch 00013: val_acc did not improve from 0.66779
# 18/18 [==============================] - 13s 697ms/step - loss: 0.5282 - dice_coef: 0.8302 - acc: 0.8065 - val_loss: 1.4365 - val_dice_coef: 0.6635 - val_acc: 0.6274
# Epoch 14/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5598 - dice_coef: 0.8180 - acc: 0.7935Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.2108 - dice_coef: 0.6451 - acc: 0.6434
# Epoch 00014: val_acc did not improve from 0.66779
# 18/18 [==============================] - 12s 687ms/step - loss: 0.5669 - dice_coef: 0.8158 - acc: 0.7906 - val_loss: 1.2108 - val_dice_coef: 0.6451 - val_acc: 0.6434
# Epoch 15/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5340 - dice_coef: 0.8314 - acc: 0.8030Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.0279 - dice_coef: 0.7146 - acc: 0.6677
# Epoch 00015: val_acc did not improve from 0.66779
# 18/18 [==============================] - 12s 686ms/step - loss: 0.5375 - dice_coef: 0.8303 - acc: 0.8012 - val_loss: 1.0279 - val_dice_coef: 0.7146 - val_acc: 0.6677
# Epoch 16/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5207 - dice_coef: 0.8320 - acc: 0.8051Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.1066 - dice_coef: 0.6908 - acc: 0.6564
# Epoch 00016: val_acc did not improve from 0.66779
# 18/18 [==============================] - 13s 696ms/step - loss: 0.5177 - dice_coef: 0.8328 - acc: 0.8058 - val_loss: 1.1066 - val_dice_coef: 0.6908 - val_acc: 0.6564
# Epoch 17/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5508 - dice_coef: 0.8237 - acc: 0.7920Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9597 - dice_coef: 0.7421 - acc: 0.7074
# Epoch 00017: val_acc improved from 0.66779 to 0.70744, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 13s 697ms/step - loss: 0.5503 - dice_coef: 0.8234 - acc: 0.7914 - val_loss: 0.9597 - val_dice_coef: 0.7421 - val_acc: 0.7074
# Epoch 18/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5335 - dice_coef: 0.8219 - acc: 0.8016Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.4286 - dice_coef: 0.5895 - acc: 0.5042
# Epoch 00018: val_acc did not improve from 0.70744
# 18/18 [==============================] - 12s 676ms/step - loss: 0.5300 - dice_coef: 0.8232 - acc: 0.8038 - val_loss: 1.4286 - val_dice_coef: 0.5895 - val_acc: 0.5042
# Epoch 19/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4777 - dice_coef: 0.8436 - acc: 0.8174Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.2466 - dice_coef: 0.7010 - acc: 0.7171
# Epoch 00019: val_acc improved from 0.70744 to 0.71707, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 12s 689ms/step - loss: 0.4815 - dice_coef: 0.8430 - acc: 0.8170 - val_loss: 1.2466 - val_dice_coef: 0.7010 - val_acc: 0.7171
# Epoch 20/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5109 - dice_coef: 0.8348 - acc: 0.8105Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.3453 - dice_coef: 0.6784 - acc: 0.5812
# Epoch 00020: val_acc did not improve from 0.71707
# 18/18 [==============================] - 12s 674ms/step - loss: 0.5067 - dice_coef: 0.8361 - acc: 0.8119 - val_loss: 1.3453 - val_dice_coef: 0.6784 - val_acc: 0.5812
# Epoch 21/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4652 - dice_coef: 0.8531 - acc: 0.8299Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9152 - dice_coef: 0.7536 - acc: 0.7242
# Epoch 00021: val_acc improved from 0.71707 to 0.72422, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 13s 695ms/step - loss: 0.4696 - dice_coef: 0.8515 - acc: 0.8279 - val_loss: 0.9152 - val_dice_coef: 0.7536 - val_acc: 0.7242
# Epoch 22/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4954 - dice_coef: 0.8431 - acc: 0.8169Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.1314 - dice_coef: 0.6494 - acc: 0.5924
# Epoch 00022: val_acc did not improve from 0.72422
# 18/18 [==============================] - 12s 664ms/step - loss: 0.4956 - dice_coef: 0.8428 - acc: 0.8168 - val_loss: 1.1314 - val_dice_coef: 0.6494 - val_acc: 0.5924
# Epoch 23/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4600 - dice_coef: 0.8522 - acc: 0.8296Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.2060 - dice_coef: 0.6539 - acc: 0.5991
# Epoch 00023: val_acc did not improve from 0.72422
# 18/18 [==============================] - 12s 676ms/step - loss: 0.4576 - dice_coef: 0.8530 - acc: 0.8306 - val_loss: 1.2060 - val_dice_coef: 0.6539 - val_acc: 0.5991
# Epoch 24/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4337 - dice_coef: 0.8624 - acc: 0.8412Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.0571 - dice_coef: 0.6828 - acc: 0.6244
# Epoch 00024: val_acc did not improve from 0.72422
# 18/18 [==============================] - 12s 676ms/step - loss: 0.4299 - dice_coef: 0.8637 - acc: 0.8430 - val_loss: 1.0571 - val_dice_coef: 0.6828 - val_acc: 0.6244
# Epoch 25/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4515 - dice_coef: 0.8592 - acc: 0.8337Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.7756 - dice_coef: 0.7795 - acc: 0.7415
# Epoch 00025: val_acc improved from 0.72422 to 0.74152, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 12s 690ms/step - loss: 0.4511 - dice_coef: 0.8596 - acc: 0.8348 - val_loss: 0.7756 - val_dice_coef: 0.7795 - val_acc: 0.7415
# Epoch 26/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4438 - dice_coef: 0.8591 - acc: 0.8372Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.4653 - dice_coef: 0.5497 - acc: 0.4855
# Epoch 00026: val_acc did not improve from 0.74152
# 18/18 [==============================] - 12s 665ms/step - loss: 0.4404 - dice_coef: 0.8603 - acc: 0.8385 - val_loss: 1.4653 - val_dice_coef: 0.5497 - val_acc: 0.4855
# Epoch 27/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.4452 - dice_coef: 0.8606 - acc: 0.8361Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 2.4221 - dice_coef: 0.4634 - acc: 0.4184
# Epoch 00027: val_acc did not improve from 0.74152
# 18/18 [==============================] - 12s 670ms/step - loss: 0.4462 - dice_coef: 0.8602 - acc: 0.8353 - val_loss: 2.4221 - val_dice_coef: 0.4634 - val_acc: 0.4184
# Epoch 28/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3973 - dice_coef: 0.8743 - acc: 0.8527Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 2.1674 - dice_coef: 0.5074 - acc: 0.4614
# Epoch 00028: val_acc did not improve from 0.74152
# 18/18 [==============================] - 12s 668ms/step - loss: 0.3984 - dice_coef: 0.8740 - acc: 0.8525 - val_loss: 2.1674 - val_dice_coef: 0.5074 - val_acc: 0.4614
# Epoch 29/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3964 - dice_coef: 0.8739 - acc: 0.8547Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.6069 - dice_coef: 0.6011 - acc: 0.5354
# Epoch 00029: val_acc did not improve from 0.74152
# 18/18 [==============================] - 12s 667ms/step - loss: 0.3965 - dice_coef: 0.8740 - acc: 0.8549 - val_loss: 1.6069 - val_dice_coef: 0.6011 - val_acc: 0.5354
# Epoch 30/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3708 - dice_coef: 0.8826 - acc: 0.8675Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.8987 - dice_coef: 0.7416 - acc: 0.6975
# Epoch 00030: val_acc did not improve from 0.74152
# 18/18 [==============================] - 12s 671ms/step - loss: 0.3716 - dice_coef: 0.8822 - acc: 0.8670 - val_loss: 0.8987 - val_dice_coef: 0.7416 - val_acc: 0.6975
# Epoch 31/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3609 - dice_coef: 0.8828 - acc: 0.8696Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.9397 - dice_coef: 0.7790 - acc: 0.7466
# Epoch 00031: val_acc improved from 0.74152 to 0.74663, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 12s 687ms/step - loss: 0.3608 - dice_coef: 0.8833 - acc: 0.8701 - val_loss: 0.9397 - val_dice_coef: 0.7790 - val_acc: 0.7466
# Epoch 32/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3413 - dice_coef: 0.8909 - acc: 0.8785Epoch 1/80
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.7923 - dice_coef: 0.7678 - acc: 0.7392
# Epoch 00032: val_acc did not improve from 0.74663
# 18/18 [==============================] - 12s 664ms/step - loss: 0.3395 - dice_coef: 0.8912 - acc: 0.8790 - val_loss: 0.7923 - val_dice_coef: 0.7678 - val_acc: 0.7392
# Epoch 33/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3097 - dice_coef: 0.8977 - acc: 0.8884Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.8163 - dice_coef: 0.7521 - acc: 0.7144
# Epoch 00033: val_acc did not improve from 0.74663
# 18/18 [==============================] - 12s 675ms/step - loss: 0.3108 - dice_coef: 0.8972 - acc: 0.8878 - val_loss: 0.8163 - val_dice_coef: 0.7521 - val_acc: 0.7144
# Epoch 34/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3149 - dice_coef: 0.8938 - acc: 0.8885Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.7974 - dice_coef: 0.7657 - acc: 0.7385
# Epoch 00034: val_acc did not improve from 0.74663
# 18/18 [==============================] - 12s 669ms/step - loss: 0.3146 - dice_coef: 0.8941 - acc: 0.8884 - val_loss: 0.7974 - val_dice_coef: 0.7657 - val_acc: 0.7385
# Epoch 35/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3124 - dice_coef: 0.8933 - acc: 0.8879Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.7761 - dice_coef: 0.7749 - acc: 0.7492
# Epoch 00035: val_acc improved from 0.74663 to 0.74916, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 12s 691ms/step - loss: 0.3201 - dice_coef: 0.8912 - acc: 0.8859 - val_loss: 0.7761 - val_dice_coef: 0.7749 - val_acc: 0.7492
# Epoch 36/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2993 - dice_coef: 0.9012 - acc: 0.8931Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 1.5107 - dice_coef: 0.5706 - acc: 0.5146
# Epoch 00036: val_acc did not improve from 0.74916
# 18/18 [==============================] - 12s 669ms/step - loss: 0.3000 - dice_coef: 0.9009 - acc: 0.8928 - val_loss: 1.5107 - val_dice_coef: 0.5706 - val_acc: 0.5146
# Epoch 37/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2935 - dice_coef: 0.9002 - acc: 0.8930Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8398 - dice_coef: 0.7745 - acc: 0.7420
# Epoch 00037: val_acc did not improve from 0.74916
# 18/18 [==============================] - 12s 685ms/step - loss: 0.2965 - dice_coef: 0.8990 - acc: 0.8921 - val_loss: 0.8398 - val_dice_coef: 0.7745 - val_acc: 0.7420
# Epoch 38/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2942 - dice_coef: 0.9019 - acc: 0.8935Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8369 - dice_coef: 0.7629 - acc: 0.7411
# Epoch 00038: val_acc did not improve from 0.74916
# 18/18 [==============================] - 12s 684ms/step - loss: 0.2919 - dice_coef: 0.9026 - acc: 0.8944 - val_loss: 0.8369 - val_dice_coef: 0.7629 - val_acc: 0.7411
# Epoch 39/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3290 - dice_coef: 0.8959 - acc: 0.8789Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 2.7300 - dice_coef: 0.5020 - acc: 0.4642
# Epoch 00039: val_acc did not improve from 0.74916
# 18/18 [==============================] - 12s 670ms/step - loss: 0.3250 - dice_coef: 0.8972 - acc: 0.8806 - val_loss: 2.7300 - val_dice_coef: 0.5020 - val_acc: 0.4642
# Epoch 40/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3053 - dice_coef: 0.9008 - acc: 0.8915Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.2766 - dice_coef: 0.7798 - acc: 0.7555
# Epoch 00040: val_acc improved from 0.74916 to 0.75550, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 13s 701ms/step - loss: 0.3042 - dice_coef: 0.9012 - acc: 0.8922 - val_loss: 1.2766 - val_dice_coef: 0.7798 - val_acc: 0.7555
# Epoch 41/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2833 - dice_coef: 0.9032 - acc: 0.8973Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.0754 - dice_coef: 0.7381 - acc: 0.7039
# Epoch 00041: val_acc did not improve from 0.75550
# 18/18 [==============================] - 12s 659ms/step - loss: 0.2844 - dice_coef: 0.9030 - acc: 0.8973 - val_loss: 1.0754 - val_dice_coef: 0.7381 - val_acc: 0.7039
# Epoch 42/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2585 - dice_coef: 0.9118 - acc: 0.9059Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.9832 - dice_coef: 0.7523 - acc: 0.7098
# Epoch 00042: val_acc did not improve from 0.75550
# 18/18 [==============================] - 12s 675ms/step - loss: 0.2565 - dice_coef: 0.9126 - acc: 0.9067 - val_loss: 0.9832 - val_dice_coef: 0.7523 - val_acc: 0.7098
# Epoch 43/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2246 - dice_coef: 0.9214 - acc: 0.9189Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.2722 - dice_coef: 0.6542 - acc: 0.6024
# Epoch 00043: val_acc did not improve from 0.75550
# 18/18 [==============================] - 12s 671ms/step - loss: 0.2241 - dice_coef: 0.9216 - acc: 0.9191 - val_loss: 1.2722 - val_dice_coef: 0.6542 - val_acc: 0.6024
# Epoch 44/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2230 - dice_coef: 0.9226 - acc: 0.9200Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8400 - dice_coef: 0.7771 - acc: 0.7527
# Epoch 00044: val_acc did not improve from 0.75550
# 18/18 [==============================] - 12s 676ms/step - loss: 0.2211 - dice_coef: 0.9227 - acc: 0.9205 - val_loss: 0.8400 - val_dice_coef: 0.7771 - val_acc: 0.7527
# Epoch 45/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2038 - dice_coef: 0.9262 - acc: 0.9264Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.7695 - dice_coef: 0.7743 - acc: 0.7519
# Epoch 00045: val_acc did not improve from 0.75550
# 18/18 [==============================] - 12s 685ms/step - loss: 0.2035 - dice_coef: 0.9261 - acc: 0.9265 - val_loss: 0.7695 - val_dice_coef: 0.7743 - val_acc: 0.7519
# Epoch 46/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1908 - dice_coef: 0.9255 - acc: 0.9312Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.8606 - dice_coef: 0.7921 - acc: 0.7725
# Epoch 00046: val_acc improved from 0.75550 to 0.77255, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 12s 690ms/step - loss: 0.1945 - dice_coef: 0.9239 - acc: 0.9297 - val_loss: 0.8606 - val_dice_coef: 0.7921 - val_acc: 0.7725
# Epoch 47/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1988 - dice_coef: 0.9224 - acc: 0.9281Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8902 - dice_coef: 0.7835 - acc: 0.7627
# Epoch 00047: val_acc did not improve from 0.77255
# 18/18 [==============================] - 12s 674ms/step - loss: 0.1981 - dice_coef: 0.9226 - acc: 0.9283 - val_loss: 0.8902 - val_dice_coef: 0.7835 - val_acc: 0.7627
# Epoch 48/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2016 - dice_coef: 0.9205 - acc: 0.9279Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 10s - loss: 0.8024 - dice_coef: 0.7862 - acc: 0.7680
# Epoch 00048: val_acc did not improve from 0.77255
# 18/18 [==============================] - 12s 691ms/step - loss: 0.1992 - dice_coef: 0.9209 - acc: 0.9287 - val_loss: 0.8024 - val_dice_coef: 0.7862 - val_acc: 0.7680
# Epoch 49/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1896 - dice_coef: 0.9223 - acc: 0.9309Epoch 1/80Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8273 - dice_coef: 0.7878 - acc: 0.7749
# Epoch 00049: val_acc improved from 0.77255 to 0.77491, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 13s 716ms/step - loss: 0.1922 - dice_coef: 0.9216 - acc: 0.9302 - val_loss: 0.8273 - val_dice_coef: 0.7878 - val_acc: 0.7749
# Epoch 50/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1840 - dice_coef: 0.9206 - acc: 0.9325Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9025 - dice_coef: 0.7741 - acc: 0.7544
# Epoch 00050: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 676ms/step - loss: 0.1832 - dice_coef: 0.9207 - acc: 0.9329 - val_loss: 0.9025 - val_dice_coef: 0.7741 - val_acc: 0.7544
# Epoch 51/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1784 - dice_coef: 0.9209 - acc: 0.9344Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8262 - dice_coef: 0.7537 - acc: 0.7512
# Epoch 00051: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 694ms/step - loss: 0.1797 - dice_coef: 0.9209 - acc: 0.9341 - val_loss: 0.8262 - val_dice_coef: 0.7537 - val_acc: 0.7512
# Epoch 52/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1695 - dice_coef: 0.9274 - acc: 0.9375Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9814 - dice_coef: 0.7062 - acc: 0.6970
# Epoch 00052: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 686ms/step - loss: 0.1702 - dice_coef: 0.9270 - acc: 0.9374 - val_loss: 0.9814 - val_dice_coef: 0.7062 - val_acc: 0.6970
# Epoch 53/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1754 - dice_coef: 0.9244 - acc: 0.9359Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9217 - dice_coef: 0.7681 - acc: 0.7630
# Epoch 00053: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 688ms/step - loss: 0.1771 - dice_coef: 0.9236 - acc: 0.9351 - val_loss: 0.9217 - val_dice_coef: 0.7681 - val_acc: 0.7630
# Epoch 54/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1591 - dice_coef: 0.9294 - acc: 0.9416Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9314 - dice_coef: 0.7633 - acc: 0.7566
# Epoch 00054: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 708ms/step - loss: 0.1586 - dice_coef: 0.9293 - acc: 0.9416 - val_loss: 0.9314 - val_dice_coef: 0.7633 - val_acc: 0.7566
# Epoch 55/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1577 - dice_coef: 0.9221 - acc: 0.9417Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.0833 - dice_coef: 0.7174 - acc: 0.6956
# Epoch 00055: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 689ms/step - loss: 0.1577 - dice_coef: 0.9223 - acc: 0.9416 - val_loss: 1.0833 - val_dice_coef: 0.7174 - val_acc: 0.6956
# Epoch 56/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1572 - dice_coef: 0.9259 - acc: 0.9421Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8190 - dice_coef: 0.7482 - acc: 0.7478
# Epoch 00056: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 701ms/step - loss: 0.1564 - dice_coef: 0.9262 - acc: 0.9423 - val_loss: 0.8190 - val_dice_coef: 0.7482 - val_acc: 0.7478
# Epoch 57/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1423 - dice_coef: 0.9287 - acc: 0.9471Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8651 - dice_coef: 0.7320 - acc: 0.7448
# Epoch 00057: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 695ms/step - loss: 0.1406 - dice_coef: 0.9295 - acc: 0.9477 - val_loss: 0.8651 - val_dice_coef: 0.7320 - val_acc: 0.7448
# Epoch 58/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1333 - dice_coef: 0.9273 - acc: 0.9503Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9081 - dice_coef: 0.7473 - acc: 0.7589
# Epoch 00058: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 692ms/step - loss: 0.1326 - dice_coef: 0.9274 - acc: 0.9506 - val_loss: 0.9081 - val_dice_coef: 0.7473 - val_acc: 0.7589
# Epoch 59/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1311 - dice_coef: 0.9258 - acc: 0.9510Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8952 - dice_coef: 0.7378 - acc: 0.7379
# Epoch 00059: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 693ms/step - loss: 0.1293 - dice_coef: 0.9266 - acc: 0.9517 - val_loss: 0.8952 - val_dice_coef: 0.7378 - val_acc: 0.7379
# Epoch 60/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1334 - dice_coef: 0.9211 - acc: 0.9499Epoch 1/80
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8063 - dice_coef: 0.7197 - acc: 0.7627
# Epoch 00060: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 697ms/step - loss: 0.1327 - dice_coef: 0.9212 - acc: 0.9501 - val_loss: 0.8063 - val_dice_coef: 0.7197 - val_acc: 0.7627
# Epoch 61/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1306 - dice_coef: 0.9240 - acc: 0.9510Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8836 - dice_coef: 0.7651 - acc: 0.7715
# Epoch 00061: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 693ms/step - loss: 0.1306 - dice_coef: 0.9241 - acc: 0.9510 - val_loss: 0.8836 - val_dice_coef: 0.7651 - val_acc: 0.7715
# Epoch 62/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1250 - dice_coef: 0.9263 - acc: 0.9531Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9747 - dice_coef: 0.6920 - acc: 0.7342
# Epoch 00062: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 693ms/step - loss: 0.1245 - dice_coef: 0.9266 - acc: 0.9533 - val_loss: 0.9747 - val_dice_coef: 0.6920 - val_acc: 0.7342
# Epoch 63/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1181 - dice_coef: 0.9269 - acc: 0.9559Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9853 - dice_coef: 0.7619 - acc: 0.7607
# Epoch 00063: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 706ms/step - loss: 0.1171 - dice_coef: 0.9275 - acc: 0.9563 - val_loss: 0.9853 - val_dice_coef: 0.7619 - val_acc: 0.7607
# Epoch 64/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1152 - dice_coef: 0.9293 - acc: 0.9566Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.8515 - dice_coef: 0.5442 - acc: 0.5558
# Epoch 00064: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 694ms/step - loss: 0.1155 - dice_coef: 0.9291 - acc: 0.9565 - val_loss: 1.8515 - val_dice_coef: 0.5442 - val_acc: 0.5558
# Epoch 65/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1084 - dice_coef: 0.9285 - acc: 0.9593Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9029 - dice_coef: 0.7003 - acc: 0.7436
# Epoch 00065: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 699ms/step - loss: 0.1074 - dice_coef: 0.9290 - acc: 0.9597 - val_loss: 0.9029 - val_dice_coef: 0.7003 - val_acc: 0.7436
# Epoch 66/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1089 - dice_coef: 0.9254 - acc: 0.9591Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9886 - dice_coef: 0.6669 - acc: 0.7120
# Epoch 00066: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 698ms/step - loss: 0.1082 - dice_coef: 0.9255 - acc: 0.9595 - val_loss: 0.9886 - val_dice_coef: 0.6669 - val_acc: 0.7120
# Epoch 67/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1098 - dice_coef: 0.9199 - acc: 0.9584Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.7570 - dice_coef: 0.7445 - acc: 0.7264
# Epoch 00067: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 695ms/step - loss: 0.1096 - dice_coef: 0.9196 - acc: 0.9585 - val_loss: 1.7570 - val_dice_coef: 0.7445 - val_acc: 0.7264
# Epoch 68/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1463 - dice_coef: 0.9131 - acc: 0.9459Epoch 1/80
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.2299 - dice_coef: 0.7235 - acc: 0.7365
# Epoch 00068: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 707ms/step - loss: 0.1469 - dice_coef: 0.9133 - acc: 0.9459 - val_loss: 1.2299 - val_dice_coef: 0.7235 - val_acc: 0.7365
# Epoch 69/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2044 - dice_coef: 0.9060 - acc: 0.9246Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 8.0122 - dice_coef: 0.3838 - acc: 0.3830
# Epoch 00069: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 696ms/step - loss: 0.2064 - dice_coef: 0.9054 - acc: 0.9239 - val_loss: 8.0122 - val_dice_coef: 0.3838 - val_acc: 0.3830
# Epoch 70/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2949 - dice_coef: 0.8966 - acc: 0.8917Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.9960 - dice_coef: 0.6086 - acc: 0.6241
# Epoch 00070: val_acc did not improve from 0.77491
# 18/18 [==============================] - 13s 697ms/step - loss: 0.2968 - dice_coef: 0.8964 - acc: 0.8913 - val_loss: 1.9960 - val_dice_coef: 0.6086 - val_acc: 0.6241
# Epoch 71/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2598 - dice_coef: 0.9141 - acc: 0.9056Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.4815 - dice_coef: 0.6827 - acc: 0.6629
# Epoch 00071: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 691ms/step - loss: 0.2570 - dice_coef: 0.9150 - acc: 0.9065 - val_loss: 1.4815 - val_dice_coef: 0.6827 - val_acc: 0.6629
# Epoch 72/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2145 - dice_coef: 0.9265 - acc: 0.9218Epoch 1/80
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.4882 - dice_coef: 0.7354 - acc: 0.7090
# Epoch 00072: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 687ms/step - loss: 0.2154 - dice_coef: 0.9260 - acc: 0.9214 - val_loss: 1.4882 - val_dice_coef: 0.7354 - val_acc: 0.7090
# Epoch 73/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1752 - dice_coef: 0.9311 - acc: 0.9360Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 3.9675 - dice_coef: 0.4455 - acc: 0.4350
# Epoch 00073: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 682ms/step - loss: 0.1747 - dice_coef: 0.9310 - acc: 0.9362 - val_loss: 3.9675 - val_dice_coef: 0.4455 - val_acc: 0.4350
# Epoch 74/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1661 - dice_coef: 0.9343 - acc: 0.9394Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 2.0463 - dice_coef: 0.5594 - acc: 0.5540
# Epoch 00074: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 691ms/step - loss: 0.1663 - dice_coef: 0.9342 - acc: 0.9393 - val_loss: 2.0463 - val_dice_coef: 0.5594 - val_acc: 0.5540
# Epoch 75/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1336 - dice_coef: 0.9433 - acc: 0.9506Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.9314 - dice_coef: 0.7581 - acc: 0.7385
# Epoch 00075: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 680ms/step - loss: 0.1344 - dice_coef: 0.9430 - acc: 0.9504 - val_loss: 0.9314 - val_dice_coef: 0.7581 - val_acc: 0.7385
# Epoch 76/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1188 - dice_coef: 0.9398 - acc: 0.9557Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 1.2417 - dice_coef: 0.7662 - acc: 0.7470
# Epoch 00076: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 685ms/step - loss: 0.1196 - dice_coef: 0.9391 - acc: 0.9555 - val_loss: 1.2417 - val_dice_coef: 0.7662 - val_acc: 0.7470
# Epoch 77/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1129 - dice_coef: 0.9392 - acc: 0.9578Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.8978 - dice_coef: 0.7744 - acc: 0.7642
# Epoch 00077: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 677ms/step - loss: 0.1131 - dice_coef: 0.9392 - acc: 0.9578 - val_loss: 0.8978 - val_dice_coef: 0.7744 - val_acc: 0.7642
# Epoch 78/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.1013 - dice_coef: 0.9393 - acc: 0.9620Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.9674 - dice_coef: 0.7766 - acc: 0.7692
# Epoch 00078: val_acc did not improve from 0.77491
# 18/18 [==============================] - 12s 677ms/step - loss: 0.1007 - dice_coef: 0.9393 - acc: 0.9622 - val_loss: 0.9674 - val_dice_coef: 0.7766 - val_acc: 0.7692
# Epoch 79/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0920 - dice_coef: 0.9399 - acc: 0.9654Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 9s - loss: 0.8944 - dice_coef: 0.7752 - acc: 0.7759
# Epoch 00079: val_acc improved from 0.77491 to 0.77591, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 13s 702ms/step - loss: 0.0915 - dice_coef: 0.9401 - acc: 0.9657 - val_loss: 0.8944 - val_dice_coef: 0.7752 - val_acc: 0.7759
# Epoch 80/80
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0918 - dice_coef: 0.9343 - acc: 0.9656Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 8s - loss: 0.9180 - dice_coef: 0.7696 - acc: 0.7771
# Epoch 00080: val_acc improved from 0.77591 to 0.77706, saving model to RESUNET_Guided3_epochs80_checkpoint.h5
# 18/18 [==============================] - 12s 692ms/step - loss: 0.0915 - dice_coef: 0.9345 - acc: 0.9657 - val_loss: 0.9180 - val_dice_coef: 0.7696 - val_acc: 0.7771

# %% [markdown]
# # Model Evaluation

# %%
#Load the checkpoint with greatest accuracy
model.load_weights('RESUNET_Guided3_epochs80_checkpoint.h5')

# %% [markdown]
# ### Model evaluation historical plots

# %%
# Get actual number of epochs model was trained for
N = len(result.history['loss'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("Training Loss")
plt.plot(np.arange(0, N), result.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), result.history["val_loss"], label="val_loss")
plt.ylim(0, 1)

fig.add_subplot(1,2,2)
plt.title("Training Accuracy")
plt.plot(np.arange(0, N), result.history["acc"], label="train_accuracy")
plt.plot(np.arange(0, N), result.history["val_acc"], label="val_accuracy")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
#training_gen = TrainAugmentGenerator()
testing_gen = ValAugmentGenerator()

# %% [markdown]
# ### Extract and display model frame, prediction and mask batch

# %%
import cv2 
batch_img,batch_mask = next(testing_gen)
pred_all= model.predict(batch_img)
np.shape(pred_all)
# Out:
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# (16, 256, 256, 5)

# %%
for i in range(0,np.shape(pred_all)[0]):
    
    fig = plt.figure(figsize=(20,8))
    
    ax1 = fig.add_subplot(1,3,1)
    ax1.imshow(batch_img[i])
    ax1.title.set_text('Actual frame')
    ax1.grid(b=None)
    
    
    ax2 = fig.add_subplot(1,3,2)
    ax2.set_title('Ground truth labels')
    ax2.imshow(onehot_to_rgb(batch_mask[i],id2code))
    ax2.grid(b=None)
    
    ax3 = fig.add_subplot(1,3,3)
    ax3.set_title('Predicted labels')
    predicted_image = onehot_to_rgb(pred_all[i],id2code)
    predicted_image_dir = os.path.join("/content/gdrive/My Drive/BBM419_Final/predictions_ResUnet", "predicted_" + str(i) + ".png")
    if not os.path.exists(predicted_image_dir):
      cv2.imwrite(predicted_image_dir, predicted_image)
    ax3.imshow(predicted_image)
    ax3.grid(b=None)
    
    plt.show()
